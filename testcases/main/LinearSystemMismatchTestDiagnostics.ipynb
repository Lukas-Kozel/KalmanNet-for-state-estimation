# %%
import sys
import os

notebook_path = os.getcwd() 
parent_dir = os.path.dirname(notebook_path)
project_root = os.path.dirname(parent_dir)
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
import state_NN_models
import Filters
import utils
import Systems
from utils import losses, trainer, utils
from torch.utils.data import TensorDataset, DataLoader, random_split
from state_NN_models.StateBayesianKalmanNet import StateBayesianKalmanNet
from state_NN_models.StateKalmanNet import StateKalmanNet
from state_NN_models.StateKalmanNetWithKnownR import StateKalmanNetWithKnownR

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Používané zařízení: {device}")
# Out:
# Používané zařízení: cpu
# /home/luky/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
import math
import torch

state_dim_2d = 2
obs_dim_2d = 2

# ==============================================================
# 1. SKUTEČNÝ SYSTÉM (2D Pozice - Random Walk)
# ==============================================================
# Matice identity. Vlastní čísla jsou přesně 1.0. 
# Stav nereprezentuje rychlost, jen X a Y pozici, která se posouvá pomocí šumu Q.
F_true_2d = torch.tensor([[1.0, 0.0], 
                          [0.0, 1.0]])
print("F_true_2d (Skutečná dynamika):\n", F_true_2d)

H_true_2d = torch.eye(obs_dim_2d)

Q_true_2d = torch.eye(state_dim_2d) * 0.1 # Šum procesu pohání trajektorii
R_true_2d = torch.eye(obs_dim_2d) * 2.0   # Hodně zašuměná měření

Ex0_true_2d = torch.tensor([[1.0], [0.0]])
P0_true_2d = torch.eye(state_dim_2d) * 1.5

# ==============================================================
# 2. MODEL SYSTÉMU (Zavedení čisté rotace - Mismatch)
# ==============================================================
delta_alpha_deg = 10.0
delta_alpha_rad = delta_alpha_deg * math.pi / 180.0

# Vytvoření 2D rotační matice R(Δα)
rotation_matrix = torch.tensor([
    [math.cos(delta_alpha_rad), -math.sin(delta_alpha_rad)],
    [math.sin(delta_alpha_rad),  math.cos(delta_alpha_rad)]
])

# Model předpokládá, že se poloha v každém kroku pootočí o 10 stupňů
# Vlastní čísla čisté rotační matice mají velikost přesně 1.0. EXPLOSE SE NEKONÁ!
F_model_2d = torch.matmul(rotation_matrix, F_true_2d)
print("\nF_model_2d (S chybou rotace o 10°):\n", F_model_2d)

H_model_2d = H_true_2d
Q_model_2d = Q_true_2d
R_model_2d = R_true_2d

Ex0_model_2d = Ex0_true_2d
P0_model_2d = P0_true_2d

# Incializace sys_true a sys_model zůstává stejná...
# ==============================================================
# 3. INICIALIZACE OBJEKTŮ SYSTÉMU
# ==============================================================
print("\nInicializuji 2D Linear_Canonical systém (Realita vs. Model)...")
sys_true = Systems.DynamicSystem(
    state_dim=state_dim_2d, obs_dim=obs_dim_2d,
    Ex0=Ex0_true_2d, P0=P0_true_2d,
    Q=Q_true_2d, R=R_true_2d,
    F=F_true_2d, H=H_true_2d,
    device=device
)

sys_model = Systems.DynamicSystem(
    state_dim=state_dim_2d, obs_dim=obs_dim_2d,
    Ex0=Ex0_model_2d, P0=P0_model_2d,
    Q=Q_model_2d, R=R_model_2d,
    F=F_model_2d, H=H_model_2d,
    device=device
)

print("... 2D systémy úspěšně inicializovány s modelovým mismatchem.")
# Out:
# F_true_2d (Skutečná dynamika):
#  tensor([[1., 0.],
#         [0., 1.]])
#
# F_model_2d (S chybou rotace o 10°):
#  tensor([[ 0.9848, -0.1736],
#         [ 0.1736,  0.9848]])
#
# Inicializuji 2D Linear_Canonical systém (Realita vs. Model)...
# ... 2D systémy úspěšně inicializovány s modelovým mismatchem.

# %%
import os
import matplotlib.pyplot as plt

def save_plot_eps(filename, folder_name="LinearSystemMismatchGraphs"):
    """
    Uloží aktuální matplotlib graf jako vektorový .eps soubor.
    
    Parametry:
    filename (str): Název souboru (bez přípony .eps)
    folder_name (str): Název cílové složky
    """
    # Vytvoření složky, pokud neexistuje (na stejné adresářové úrovni)
    os.makedirs(folder_name, exist_ok=True)
    
    # Sestavení absolutní cesty k souboru
    filepath = os.path.join(folder_name, f"{filename}.eps")
    
    # Uložení grafu 
    # bbox_inches='tight' je klíčové - zabrání oříznutí legendy ležící mimo osu
    plt.savefig(filepath, format='eps', bbox_inches='tight')
    print(f"--> Graf byl úspěšně uložen jako vektor: {filepath}")

# %%
TRAIN_SEQ_LEN = 50      # Krátké sekvence pro stabilní trénink (TBPTT)
VALID_SEQ_LEN = 200      # Stejná délka pro konzistentní validaci
TEST_SEQ_LEN = 1000      # Dlouhé sekvence pro testování generalizace

NUM_TRAIN_TRAJ = 500   # Hodně trénovacích příkladů
NUM_VALID_TRAJ = 50    # Dostatek pro spolehlivou validaci
NUM_TEST_TRAJ = 100     # Pro robustní vyhodnocení

BATCH_SIZE = 32         # Dobrý kompromis

x_train, y_train = utils.generate_data(sys_true, num_trajectories=NUM_TRAIN_TRAJ, seq_len=TRAIN_SEQ_LEN)
x_val, y_val = utils.generate_data(sys_true, num_trajectories=NUM_VALID_TRAJ, seq_len=VALID_SEQ_LEN)
x_test, y_test = utils.generate_data(sys_true, num_trajectories=NUM_TEST_TRAJ, seq_len=TEST_SEQ_LEN)

train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import os
import random
import csv
from datetime import datetime
import pandas as pd
from copy import deepcopy

model_config = {
    "hidden_size_multiplier": 12,
    "output_layer_multiplier": 4,
    "num_gru_layers": 1,
    "init_min_dropout": 0.2,#0.3
    "init_max_dropout": 0.3 #0.4
}

train_config = {
    "total_train_iter": 2000,
    "learning_rate": 1e-4,
    "clip_grad": 10.0,
    "J_samples": 10,
    "validation_period": 20,
    "logging_period": 10,
    "warmup_iterations": 150, # Trénuj prvních 150 iterací jen na MSE
    "store_model_based_on_hybrid_score": True,
    "calibration_parameter": 0.5
}

# =================================================================================
# KROK 3: SPUŠTĚNÍ JEDNOHO TRÉNINKOVÉHO BĚHU NEBO NAČTENÍ HOTOVÉHO MODELU
# =================================================================================
print("device:", device)
print("="*80)
print("Připravuji Bayesian KalmanNet (BKN)...")
print(f"Parametry modelu: {model_config}")
print(f"Parametry tréninku: {train_config}")
print("="*80)

# Nastavení seedu pro reprodukovatelnost tohoto běhu
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# Definice cesty ke složce a souboru
save_dir = "LinearSystemWeightsMismatch"
os.makedirs(save_dir, exist_ok=True)
weights_path = os.path.join(save_dir, "best_bkn_model_weights_mismatch-latest-test-latest.pth")

# Vytvoření modelu (potřebujeme ho inicializovat v obou případech)
state_bkn_knet = StateBayesianKalmanNet(
    sys_model,
    device=device,
    weight_init=False,
    **model_config
).to(device)

# Podmínka pro načtení nebo trénink
if os.path.exists(weights_path):
    print(f"\nINFO: Uložené váhy nalezeny v '{weights_path}'.")
    print("Přeskakuji trénink a načítám hotový model...")
    
    # Načtení vah
    state_bkn_knet.load_state_dict(torch.load(weights_path, map_location=device))
    trained_model = state_bkn_knet
    
else:
    print("\nINFO: Váhy nebyly nalezeny. Spouštím plnohodnotný tréninkový běh...")
    
    # Spuštění tréninku
    results = trainer.training_session_trajectory_with_gaussian_nll_training_fcn(
        model=state_bkn_knet,
        train_loader=train_loader,
        val_loader=val_loader,
        device=device,
        **train_config
    )

    # `run_training_session` automaticky načte nejlepší model zpět,
    # takže `state_bkn_knet` nyní obsahuje váhy nejlepšího modelu.
    trained_model = results['final_model']
    
    # Uložení vah pro příští použití
    torch.save(trained_model.state_dict(), weights_path)
    print(f"\nINFO: Váhy modelu byly úspěšně uloženy do: {weights_path}")

    # Výpis metrik pouze pokud jsme trénovali
    print("\n" + "="*80)
    print("TRÉNINK DOKONČEN - FINÁLNÍ VÝSLEDKY Z NEJLEPŠÍHO MODELU")
    print("="*80)
    print(f"Nejlepší model byl nalezen v iteraci: {results['best_iter']}")
    print(f"Nejlepší dosažený validační ANEES: {results['best_val_anees']:.4f}")
    print("--- Metriky odpovídající tomuto nejlepšímu modelu ---")
    print(f"  MSE na validační sadě:       {results['best_val_mse']:.4f}")
    print(f"  NLL na validační sadě:       {results['best_val_nll']:.4f}")
    print("="*80)

# Prepnutí do evaluačního módu na konci bloku (klíčové pro BKN kvůli Dropoutu)
trained_model.eval()
print("\nModel BKN je plně připraven v proměnné 'trained_model'.")
total_params = sum(p.numel() for p in trained_model.parameters() if p.requires_grad)
print(f"Celkový počet trénovatelných parametrů: {total_params}")
# Out:
# device: cpu
# ================================================================================
# Připravuji Bayesian KalmanNet (BKN)...
# Parametry modelu: {'hidden_size_multiplier': 12, 'output_layer_multiplier': 4, 'num_gru_layers': 1, 'init_min_dropout': 0.2, 'init_max_dropout': 0.3}
# Parametry tréninku: {'total_train_iter': 2000, 'learning_rate': 0.0001, 'clip_grad': 10.0, 'J_samples': 10, 'validation_period': 20, 'logging_period': 10, 'warmup_iterations': 150, 'store_model_based_on_hybrid_score': True, 'calibration_parameter': 0.5}
# ================================================================================
# loaded with input normalization
#
# INFO: Uložené váhy nalezeny v 'LinearSystemWeightsMismatch/best_bkn_model_weights_mismatch-latest-test-latest.pth'.
# Přeskakuji trénink a načítám hotový model...
#
# Model BKN je plně připraven v proměnné 'trained_model'.
# Celkový počet trénovatelných parametrů: 44198

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import os
import random
import csv
from datetime import datetime
import pandas as pd
from copy import deepcopy
# Nastavení seedu pro reprodukovatelnost tohoto běhu
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

save_dir = "LinearSystemWeightsMismatch"
weights_path = os.path.join(save_dir, "best_knet_model_weights_mismatch-latest-test-latest.pth")

# Vytvoření cílové složky (pokud ještě neexistuje, nic se nestane)
os.makedirs(save_dir, exist_ok=True)


state_knetR = StateKalmanNet(sys_model, device=device, hidden_size_multiplier=12,gru_hidden_dim_multiplier=4,returns_covariance=True).to(device)

if os.path.exists(weights_path):
    print(f"INFO: Uložené váhy nalezeny v '{weights_path}'.")
    print("Přeskakuji trénink a načítám hotový model...")
    
    # Načtení vah (map_location zajistí kompatibilitu, pokud bys např. trénoval na GPU a načítal na CPU)
    state_knetR.load_state_dict(torch.load(weights_path, map_location=device))
    
else:
    print("INFO: Váhy nebyly nalezeny. Spouštím trénink modelu...")
    
    # Spuštění tréninku
    trainer.train_state_KalmanNet(
        model=state_knetR, 
        train_loader=train_loader, 
        val_loader=val_loader, 
        device=device, 
        epochs=500, 
        lr=2e-4,
        early_stopping_patience=100,
        weight_decay=1e-1
    )
    
    # Po úspěšném tréninku váhy rovnou uložíme pro příští spuštění
    torch.save(state_knetR.state_dict(), weights_path)
    print(f"Trénink dokončen. Váhy byly bezpečně uloženy do '{weights_path}'.")

# Prepnutí do evaluačního módu (dobrá praxe před testováním)
state_knetR.eval()
total_params = sum(p.numel() for p in state_knetR.parameters() if p.requires_grad)
print(f"Celkový počet trénovatelných parametrů: {total_params}")
# Out:
# DEBUG: Layer 'output_final_linear.0' initialized near zero (Start K=0).
# INFO: Uložené váhy nalezeny v 'LinearSystemWeightsMismatch/best_knet_model_weights_mismatch-latest-test-latest.pth'.
# Přeskakuji trénink a načítám hotový model...
# Celkový počet trénovatelných parametrů: 44180

# %%
import torch
import numpy as np
from tqdm import tqdm

class AdaptiveKalmanFilter_mehra_offline_pretraining:
    def __init__(self, model, num_iterations=5, batch_size=None, max_lags=None):
        """
        Offline verze Mehrova filtru s podporou volitelného dávkování (batching).
        
        Parametry:
        - num_iterations: Počet iterací pro nalezení optimálního K.
        - batch_size: Pokud je zadáno (např. 500), použije se dávkové zpracování 
                      zamezující divergenci chyby u nepřesných modelů. 
                      Pokud je None, zpracovává se celá sekvence standardně v kuse.
        - max_lags: Omezení pohledu do minulosti (krok 'k'). Pokud je None, 
                    použije se standardních (nx + 1). Pro Mismatch model doporučeno 1 nebo 2.
        """
        self.device = model.Q.device
        self.model = model
        self.dtype = model.F.dtype
        self.F = model.F
        self.H = model.H
        self.nx = self.F.shape[0]
        self.nz = self.H.shape[0]
        self.num_iterations = num_iterations
        
        self.batch_size = batch_size
        self.max_lags = max_lags
        self.K = None

    def _filter_sequence(self, y_seq, Ex0):
        """STANDARDNÍ METODA: přefiltruje data jako jednu dlouhou sekvenci."""
        seq_len = y_seq.shape[0]
        inov_history = torch.zeros(self.nz, seq_len, device=self.device, dtype=self.dtype)
        x_filt_history = torch.zeros(seq_len, self.nx, device=self.device, dtype=self.dtype)
        
        xp = Ex0.clone().detach().reshape(self.nx, 1)
        
        for i in range(seq_len):
            z_i = y_seq[i].reshape(self.nz, 1)
            inov_i = z_i - self.H @ xp
            inov_history[:, i] = inov_i.squeeze()
            
            x_filtered = xp + self.K @ inov_i
            x_filt_history[i] = x_filtered.squeeze()
            xp = self.F @ x_filtered
            
        return x_filt_history, inov_history

    def _filter_sequence_batched(self, y_seq, x_true_seq):
        """DÁVKOVÁ METODA: přefiltruje data po blocích s resetem do Ground Truth."""
        seq_len = y_seq.shape[0]
        inov_list = []
        x_filt_history = torch.zeros(seq_len, self.nx, device=self.device, dtype=self.dtype)
        
        for start_idx in range(0, seq_len, self.batch_size):
            end_idx = min(start_idx + self.batch_size, seq_len)
            # Na začátku dávky vždy resetujeme na správný stav (Ground Truth)
            xp = x_true_seq[start_idx].clone().detach().reshape(self.nx, 1)
            
            for i in range(start_idx, end_idx):
                z_i = y_seq[i].reshape(self.nz, 1)
                inov_i = z_i - self.H @ xp
                inov_list.append(inov_i.squeeze())
                
                x_filtered = xp + self.K @ inov_i
                x_filt_history[i] = x_filtered.squeeze()
                xp = self.F @ x_filtered
                
        inov_history = torch.stack(inov_list, dim=1) 
        return x_filt_history, inov_history

    def estimate_K_from_data(self, y_seq, Ex0=None, x_true_seq=None):
        """
        FÁZE 1: Na základě offline dat iterativně najde optimální ustálený Kalmanův zisk K.
        Pokud je zapnutý `batch_size`, je nezbytné předat `x_true_seq`.
        """
        if Ex0 is None: Ex0 = self.model.Ex0
        
        seq_len = y_seq.shape[0]
        N = seq_len
        
        # Robustnější počáteční nástřel zisku (více věří měření, méně chybnému modelu)
        self.K = 0.1 * torch.linalg.pinv(self.H)
        
        lags_to_use = self.max_lags if self.max_lags is not None else (self.nx + 1)
        
        mode_str = "Dávkový (Batched)" if self.batch_size else "Standardní (Continuous)"
        print(f"\n--- Offline Mehra: Start adaptace K | Režim: {mode_str} | Lags: {lags_to_use} ---")
        
        for m in tqdm(range(self.num_iterations), desc="Hledání optimálního K (Mehra)", leave=False):
            A = self.F - self.F @ self.K @ self.H

            # ROZHODOVÁNÍ O ZPRACOVÁNÍ NA ZÁKLADĚ ARGUMENTU `batch_size`
            if self.batch_size is not None and self.batch_size > 0:
                if x_true_seq is None:
                    raise ValueError("Pro dávkovou verzi (batching) musíte předat 'x_true_seq' argument!")
                x_filt_hist, inov = self._filter_sequence_batched(y_seq, x_true_seq)
            else:
                x_filt_hist, inov = self._filter_sequence(y_seq, Ex0)
            
            Py0 = (inov @ inov.T) / N
            Py_list = []
            G_list = []
            
            for k in range(1, lags_to_use + 1):
                inov_shift = inov[:, k:]
                inov_orig = inov[:, :-k]
                
                Py_k = (inov_shift @ inov_orig.T) / (N - k)
                Py_list.append(Py_k)
                
                A_pow = torch.matrix_power(A, k - 1)
                G_k = self.H @ A_pow @ self.F
                G_list.append(G_k)
                
            Py = torch.cat(Py_list, dim=0)
            G = torch.cat(G_list, dim=0)
            
            # Robustnější inverze pro obcházení kolinearity
            PHT = self.K @ Py0 + torch.linalg.pinv(G, rcond=1e-3) @ Py
            K_est = PHT @ torch.linalg.pinv(Py0, rcond=1e-3)
            
            # Kontrola stability nového K
            A_next = self.F - self.F @ K_est @ self.H
            eigvals = torch.linalg.eigvals(A_next)
            if torch.max(torch.abs(eigvals)) >= 1.0:
                print(f"Varování: V iteraci {m} se filtr stal nestabilním. Končím iterace.")
                break 
        
            self.K = K_est
            
        print(f"--- Offline Mehra: Adaptace dokončena ---")
        return self.K.clone().detach()

    def process_sequence_with_K(self, y_seq, K_fixed, Ex0=None):
        """
        FÁZE 2: Provede inferenci nad testovací trajektorií pomocí fixního, 
        předem naučeného zisku K. Vždy funguje standardním (nedávkovým) způsobem.
        """
        if Ex0 is None: Ex0 = self.model.Ex0
        self.K = K_fixed
        
        seq_len = y_seq.shape[0]
        final_x_filt, final_inov = self._filter_sequence(y_seq, Ex0)
        
        P_filtered_history = torch.zeros(seq_len, self.nx, self.nx, device=self.device, dtype=self.dtype)
        K_history = self.K.unsqueeze(0).repeat(seq_len, 1, 1) 
        
        return {
            'x_filtered': final_x_filt,
            'P_filtered': P_filtered_history,
            'Kalman_gain': K_history,
            'innovation': final_inov.T
        }

    def process_sequence_adaptively(self, y_seq, Ex0=None, x_true_seq=None):
        """Původní chování."""
        K_est = self.estimate_K_from_data(y_seq, Ex0, x_true_seq)
        return self.process_sequence_with_K(y_seq, K_est, Ex0)

# %%
import torch
import torch.nn.functional as F
import numpy as np
from torch.utils.data import TensorDataset, DataLoader
import Filters
from copy import deepcopy
from utils import utils

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ==============================================================================
# 1. KONFIGURACE TESTU A LADĚNÍ HYPERPARAMETRŮ
# ==============================================================================
# Parametry dat
TEST_SEQ_LEN = 500 
NUM_TEST_TRAJ = 10     
OFFLINE_SEQ_LEN = 35000 

# ---> ZDE MĚŇ NASTAVENÍ PRO ADAPTIVNÍ FILTRY <---
MDM_L_PARAM = 8        
MDM_VERSION = 2        
MEHRA_ITERATIONS = 100  
MEHRA_LAGS=5

# ==============================================================================
# 2. PŘÍPRAVA DAT 
# ==============================================================================
print(f"\nGeneruji {NUM_TEST_TRAJ} testovacích trajektorií (délka {TEST_SEQ_LEN})...")
x_test, y_test = utils.generate_data(sys_true, num_trajectories=NUM_TEST_TRAJ, seq_len=TEST_SEQ_LEN)
test_dataset = TensorDataset(x_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

print(f"Generuji 1 offline trajektorii (délka {OFFLINE_SEQ_LEN}) pro předtrénování...")
x_offline, y_offline = utils.generate_data(sys_true, num_trajectories=1, seq_len=OFFLINE_SEQ_LEN)
y_offline_gpu = y_offline.squeeze(0).to(device) 
x_offline_gpu = x_offline.squeeze(0).to(device)

# Skutečný počátek offline trajektorie pro trénink Mehry
offline_Ex0 = x_offline_gpu[0, :]

# ==============================================================================
# 3. OFFLINE IDENTIFIKACE (PŘEDTRÉNOVÁNÍ NA MISMATCH MODELU)
# ==============================================================================
akf_mdm_m = Filters.AdaptiveKalmanFilter(deepcopy(sys_model), mdm_L=MDM_L_PARAM, mdm_version=MDM_VERSION)
akf_mehra_m = AdaptiveKalmanFilter_mehra_offline_pretraining(
    deepcopy(sys_model), 
    num_iterations=MEHRA_ITERATIONS, 
    batch_size=50, # Zapne dávkování
    max_lags=MEHRA_LAGS      # Omezí lagy
)
kf_ideal = Filters.KalmanFilter(deepcopy(sys_true)) 

print(f"\n[MDM] Spouštím odhad Q a R (L={MDM_L_PARAM}, ver={MDM_VERSION})...")
Q_est_mdm, R_est_mdm = akf_mdm_m.estimate_qr_from_data(y_offline_gpu)

print(f"\n[Mehra] Spouštím odhad ustáleného zisku K ({MEHRA_ITERATIONS} iterací)...")
# OPRAVA: Použití skutečného počátku trajektorie místo sys_model.Ex0
K_est_mehra = akf_mehra_m.estimate_K_from_data(y_offline_gpu, x_true_seq=x_offline_gpu)

print("\nOffline identifikace dokončena. Jdeme na evaluaci.")

# ==============================================================================
# 4. VYHODNOCOVACÍ SMYČKA
# ==============================================================================
all_x_true_cpu = []
all_x_hat_akf_mdm_cpu, all_P_hat_akf_mdm_cpu = [], []
all_x_hat_akf_mehra_cpu = [] 
all_x_hat_kf_ideal_cpu, all_P_hat_kf_ideal_cpu = [], []

print(f"\nVyhodnocuji modely na {NUM_TEST_TRAJ} testovacích trajektoriích...")

with torch.no_grad():
    for i, (x_true_seq_batch, y_test_seq_batch) in enumerate(test_loader):
        y_test_seq_gpu = y_test_seq_batch.squeeze(0).to(device)
        x_true_seq_gpu = x_true_seq_batch.squeeze(0).to(device)
        
        # OPRAVA: Skutečný počátek pro TUTO konkrétní testovací trajektorii
        initial_state = x_true_seq_gpu[0, :]
        
        # --- A. AKF-MDM (Mismatched) ---
        afk_mdm_m_res = akf_mdm_m.process_sequence_with_qr(
            y_test_seq_gpu, Q_est_mdm, R_est_mdm, Ex0=initial_state, P0=sys_model.P0
        )
        all_x_hat_akf_mdm_cpu.append(afk_mdm_m_res['x_filtered'].cpu())
        all_P_hat_akf_mdm_cpu.append(afk_mdm_m_res['P_filtered'].cpu()) 

        # --- B. AKF-Mehra (Mismatched) ---
        akf_mehra_m_res = akf_mehra_m.process_sequence_with_K(
            y_test_seq_gpu, K_fixed=K_est_mehra, Ex0=initial_state
        )
        all_x_hat_akf_mehra_cpu.append(akf_mehra_m_res['x_filtered'].cpu())   

        # --- C. Ideální KF (Benchmark) ---
        kf_i_res = kf_ideal.process_sequence(y_test_seq_gpu, Ex0=initial_state, P0=sys_true.P0)
        all_x_hat_kf_ideal_cpu.append(kf_i_res['x_filtered'].cpu())
        all_P_hat_kf_ideal_cpu.append(kf_i_res['P_filtered'].cpu())
        
        all_x_true_cpu.append(x_true_seq_gpu.cpu())

# ==============================================================================
# 5. FINÁLNÍ VÝPOČET A VÝPIS METRIK
# ==============================================================================
mse_akf_mdm, anees_akf_mdm = [], []
mse_akf_mehra = [] 
mse_kf_ideal, anees_kf_ideal = [], []

with torch.no_grad():
    for i in range(NUM_TEST_TRAJ):
        x_true = all_x_true_cpu[i]
        
        def get_metrics(x_hat, P_hat):
            mse = F.mse_loss(x_hat[1:], x_true[1:]).item()
            anees = utils.calculate_anees_vectorized(x_true.unsqueeze(0), x_hat.unsqueeze(0), P_hat.unsqueeze(0))
            return mse, anees

        # MDM
        mse, anees = get_metrics(all_x_hat_akf_mdm_cpu[i], all_P_hat_akf_mdm_cpu[i])
        mse_akf_mdm.append(mse)
        anees_akf_mdm.append(anees)
        
        # Mehra
        mse_akf_mehra.append(F.mse_loss(all_x_hat_akf_mehra_cpu[i][1:], x_true[1:]).item())
        
        # Ideal Benchmark
        mse, anees = get_metrics(all_x_hat_kf_ideal_cpu[i], all_P_hat_kf_ideal_cpu[i])
        mse_kf_ideal.append(mse)
        anees_kf_ideal.append(anees)

def avg(metric_list): return np.mean([m for m in metric_list if not np.isnan(m)])
state_dim_for_nees = all_x_true_cpu[0].shape[1]

# --- VÝPIS ---
print("\n" + "="*85)
print(f"LADĚNÍ ADAPTIVNÍCH FILTRŮ: MODEL MISMATCH SCÉNÁŘ (průměr přes {NUM_TEST_TRAJ} běhů)")
print("="*85)
print(f"{'Model':<35} | {'Průměrné MSE':<20} | {'Průměrný ANEES':<20}")
print("-" * 85)
print(f"{'AKF-MDM (Nepřesný model)':<35} | {avg(mse_akf_mdm):<20.4f} | {avg(anees_akf_mdm):<20.4f}")
print(f"{'AKF-Mehra (Nepřesný model)':<35} | {avg(mse_akf_mehra):<20.4f} | {'N/A':<20}")
print("-" * 85)
print(f"{'KF (Ideální model - OPTIMUM)':<35} | {avg(mse_kf_ideal):<20.4f} | {avg(anees_kf_ideal):<20.4f}")
print("="*85)
# Out:
# Generuji 10 testovacích trajektorií (délka 500)...
# Generuji 1 offline trajektorii (délka 35000) pro předtrénování...
#
# [MDM] Spouštím odhad Q a R (L=8, ver=2)...
# Spouštím MDM odhad Q a R...
# MDM odhad dokončen.
# Odhadnuté Q:
#  [[ 80.2841 126.3704]
#  [126.3704 201.6806]]
# Odhadnuté R:
#  [[ 5.4772 -4.2936]
#  [-4.2936  3.3658]]
#
# [Mehra] Spouštím odhad ustáleného zisku K (100 iterací)...
#
# --- Offline Mehra: Start adaptace K | Režim: Dávkový (Batched) | Lags: 5 ---
# --- Offline Mehra: Adaptace dokončena ---
#
# Offline identifikace dokončena. Jdeme na evaluaci.
#
# Vyhodnocuji modely na 10 testovacích trajektoriích...
# =====================================================================================
# LADĚNÍ ADAPTIVNÍCH FILTRŮ: MODEL MISMATCH SCÉNÁŘ (průměr přes 10 běhů)
# =====================================================================================
# Model                               | Průměrné MSE         | Průměrný ANEES
# -------------------------------------------------------------------------------------
# AKF-MDM (Nepřesný model)            | 2.6724               | 94804.0285
# AKF-Mehra (Nepřesný model)          | 7.0693               | N/A
# -------------------------------------------------------------------------------------
# KF (Ideální model - OPTIMUM)        | 0.4023               | 2.0037
# =====================================================================================

# %%
import torch
import torch.nn.functional as F
import numpy as np
from torch.utils.data import TensorDataset, DataLoader
import Filters
from copy import deepcopy  # <-- ZÁSADNÍ IMPORT
from utils import utils

# ==============================================================================
# 0. PŘEDPOKLADY - ZDE PŘIŘAĎTE VAŠE NATRÉNOVANÉ MODELY
# ==============================================================================
# POZNÁMKA: Sítě trained_model_bkn a trained_model_knetR musí být inicializovány 
# s objektem `sys_model` (chybná dynamika) před spuštěním tohoto skriptu!
try:
    trained_model_bkn = trained_model
    trained_model_knetR = state_knetR
    print("INFO: Všechny natrénované modely nalezeny a přiřazeny.")
except NameError:
    print("VAROVÁNÍ: Některé z proměnných `trained_model`, nebo `state_knetR` nebyly nalezeny.")
    print("         Ujistěte se, že jste nejprve úspěšně dokončili trénink všech modelů.")

# ==============================================================================
# 1. KONFIGURACE TESTU
# ==============================================================================
# POZOR: Nastaveno na 500
TEST_SEQ_LEN = 500 
NUM_TEST_TRAJ = 2
J_SAMPLES_TEST = 50
# Délka odpovídající trénovací + validační sadě (10*500 + 20*200) pro adaptivní metody
OFFLINE_SEQ_LEN = 535000 

# ==============================================================================
# 2.A PŘÍPRAVA TESTOVACÍCH DAT (Generováno z ideálního / skutečného světa)
# ==============================================================================
print(f"\nGeneruji {NUM_TEST_TRAJ} testovacích trajektorií o délce {TEST_SEQ_LEN}...")
# Data generujeme VŽDY pomocí sys_true (skutečná fyzika)
x_test, y_test = utils.generate_data(sys_true, num_trajectories=NUM_TEST_TRAJ, seq_len=TEST_SEQ_LEN)
test_dataset = TensorDataset(x_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
print("Generování dat dokončeno.")

# ==============================================================================
# 2.B PŘÍPRAVA OFFLINE DAT A PŘEDTRÉNOVÁNÍ ADAPTIVNÍCH FILTRŮ (MISMATCH SCENARIO)
# ==============================================================================
print(f"\nGeneruji 1 trajektorii o délce {OFFLINE_SEQ_LEN} pro offline identifikaci...")
_, y_offline = utils.generate_data(sys_true, num_trajectories=1, seq_len=OFFLINE_SEQ_LEN)
y_offline_gpu = y_offline.squeeze(0).to(device) 

# Adaptivní filtry dostávají do vínku NEPŘESNÝ model (sys_model), ale data z reálného světa
akf_mdm_mismatched = Filters.AdaptiveKalmanFilter(deepcopy(sys_model), mdm_L=6, mdm_version=2)
akf_mehra_mismatched = Filters.AdaptiveKalmanFilter_mehra_offline_pretraining(deepcopy(sys_model), num_iterations=10)

print("\nSpouštím offline identifikaci Q a R (MDM) pro nepřesný model...")
Q_est_mdm_m, R_est_mdm_m = akf_mdm_mismatched.estimate_qr_from_data(y_offline_gpu)

print("\nSpouštím offline identifikaci ustáleného zisku K (Mehra) pro nepřesný model...")
K_est_mehra_m = akf_mehra_mismatched.estimate_K_from_data(y_offline_gpu, Ex0=sys_model.Ex0)

print("\nOffline identifikace MISMATCH modelů dokončena.")

# ==============================================================================
# 3. INICIALIZACE STATICKÝCH FILTRŮ (TEST NA NEPŘESNÉM MODELU)
# ==============================================================================
# Každý filtr dostane svou vlastní odizolovanou kopii systému
kf_mismatched = Filters.KalmanFilter(deepcopy(sys_model))
ekf_mismatched = Filters.ExtendedKalmanFilter(deepcopy(sys_model))
ukf_mismatched = Filters.UnscentedKalmanFilter(deepcopy(sys_model))

# Ponecháme si jeden čistě ideální KF jako referenci (Spodní mez chyby)
kf_ideal = Filters.KalmanFilter(deepcopy(sys_true))

print("Statické filtry inicializovány s oddělenými kopiemi NEPŘESNÉHO modelu (sys_model).")
print("Ideální KF inicializován s PŘESNÝM modelem (sys_true) jako benchmark.")

# ==============================================================================
# 4. VYHODNOCOVACÍ SMYČKA
# ==============================================================================
all_x_true_cpu = []
all_x_hat_bkn_cpu, all_P_hat_bkn_cpu = [], []
all_x_hat_knetR_cpu, all_P_hat_knetR_cpu = [], []
all_x_hat_kf_m_cpu, all_P_hat_kf_m_cpu = [], []
all_x_hat_ekf_m_cpu, all_P_hat_ekf_m_cpu = [], []
all_x_hat_ukf_m_cpu, all_P_hat_ukf_m_cpu = [], []
all_x_hat_akf_mdm_m_cpu, all_P_hat_akf_mdm_m_cpu = [], []
all_x_hat_akf_mehra_m_cpu = [] 
all_x_hat_kf_ideal_cpu, all_P_hat_kf_ideal_cpu = [], []

print(f"\nVyhodnocuji modely na {NUM_TEST_TRAJ} testovacích trajektoriích...")

trained_model_bkn.eval() 
trained_model_knetR.eval()

with torch.no_grad():
    for i, (x_true_seq_batch, y_test_seq_batch) in enumerate(test_loader):
        y_test_seq_gpu = y_test_seq_batch.squeeze(0).to(device)
        x_true_seq_gpu = x_true_seq_batch.squeeze(0).to(device)
        initial_state = x_true_seq_gpu[0, :].unsqueeze(0)
        
        # --- A. Bayesian KalmanNet (Trajectory-wise) ---
        ensemble_trajectories = []
        for j in range(J_SAMPLES_TEST):
            trained_model_bkn.reset(batch_size=1, initial_state=initial_state)
            current_x_hats = []
            for t in range(1, TEST_SEQ_LEN):
                x_filtered_t, _ = trained_model_bkn.step(y_test_seq_gpu[t, :].unsqueeze(0))
                current_x_hats.append(x_filtered_t)
            ensemble_trajectories.append(torch.cat(current_x_hats, dim=0))
        ensemble = torch.stack(ensemble_trajectories, dim=0)
        predictions_bkn = ensemble.mean(dim=0)
        diff = ensemble - predictions_bkn.unsqueeze(0)
        covariances_bkn = (diff.unsqueeze(-1) @ diff.unsqueeze(-2)).mean(dim=0)
        full_x_hat_bkn = torch.cat([initial_state, predictions_bkn], dim=0)
        # AI startuje z chybného P0
        full_P_hat_bkn = torch.cat([sys_model.P0.unsqueeze(0), covariances_bkn], dim=0)
        
        # --- B. StateKalmanNetWithKnownR ---
        trained_model_knetR.reset(batch_size=1, initial_state=initial_state)
        knetR_preds_x, knetR_preds_P = [], []
        for t in range(1, TEST_SEQ_LEN):
            x_filtered_t, P_filtered_t = trained_model_knetR.step(y_test_seq_gpu[t, :].unsqueeze(0))
            knetR_preds_x.append(x_filtered_t)
            knetR_preds_P.append(P_filtered_t)
        full_x_hat_knetR = torch.cat([initial_state, torch.cat(knetR_preds_x, dim=0)], dim=0)
        
        processed_P_list = []
        for p_tensor in knetR_preds_P:
            while p_tensor.dim() < 2: p_tensor = p_tensor.unsqueeze(-1)
            if p_tensor.dim() > 2 and p_tensor.shape[0] == 1: p_tensor = p_tensor.squeeze(0)
            processed_P_list.append(p_tensor)

        P_sequence_knetR = torch.stack(processed_P_list, dim=0)
        P0_for_cat = sys_model.P0.clone()
        while P0_for_cat.dim() < P_sequence_knetR.dim(): P0_for_cat = P0_for_cat.unsqueeze(0)
        full_P_hat_knetR = torch.cat([P0_for_cat, P_sequence_knetR], dim=0)

        # --- C. Klasické filtry (MISMATCHED) ---
        kf_m_res = kf_mismatched.process_sequence(y_test_seq_gpu, Ex0=sys_model.Ex0, P0=sys_model.P0)
        full_x_hat_kf_m = kf_m_res['x_filtered']
        full_P_hat_kf_m = kf_m_res['P_filtered']
        
        ekf_m_res = ekf_mismatched.process_sequence(y_test_seq_gpu, Ex0=sys_model.Ex0, P0=sys_model.P0)
        full_x_hat_ekf_m = ekf_m_res['x_filtered']
        full_P_hat_ekf_m = ekf_m_res['P_filtered']
        
        ukf_m_res = ukf_mismatched.process_sequence(y_test_seq_gpu, Ex0=sys_model.Ex0, P0=sys_model.P0)
        full_x_hat_ukf_m = ukf_m_res['x_filtered']
        full_P_hat_ukf_m = ukf_m_res['P_filtered']

        # --- D. Adaptivní filtry (Inference s naučenými daty na chybném modelu) ---
        afk_mdm_m_res = akf_mdm_mismatched.process_sequence_with_qr(
            y_test_seq_gpu, 
            Q_est_mdm_m, 
            R_est_mdm_m, 
            Ex0=sys_model.Ex0, 
            P0=sys_model.P0
        )
        full_x_hat_akf_mdm_m = afk_mdm_m_res['x_filtered']
        full_P_hat_akf_mdm_m = afk_mdm_m_res['P_filtered'] 

        akf_mehra_m_res = akf_mehra_mismatched.process_sequence_with_K(
            y_test_seq_gpu, 
            K_fixed=K_est_mehra_m, 
            Ex0=sys_model.Ex0
        )
        full_x_hat_akf_mehra_m = akf_mehra_m_res['x_filtered']   

        # --- E. Benchmark (IDEAL) ---
        kf_i_res = kf_ideal.process_sequence(y_test_seq_gpu, Ex0=sys_true.Ex0, P0=sys_true.P0)
        full_x_hat_kf_ideal = kf_i_res['x_filtered']
        full_P_hat_kf_ideal = kf_i_res['P_filtered']
        
        # Ukládání na CPU
        all_x_true_cpu.append(x_true_seq_gpu.cpu())
        all_x_hat_bkn_cpu.append(full_x_hat_bkn.cpu()); all_P_hat_bkn_cpu.append(full_P_hat_bkn.cpu())
        all_x_hat_knetR_cpu.append(full_x_hat_knetR.cpu()); all_P_hat_knetR_cpu.append(full_P_hat_knetR.cpu())
        
        all_x_hat_kf_m_cpu.append(full_x_hat_kf_m.cpu()); all_P_hat_kf_m_cpu.append(full_P_hat_kf_m.cpu())
        all_x_hat_ekf_m_cpu.append(full_x_hat_ekf_m.cpu()); all_P_hat_ekf_m_cpu.append(full_P_hat_ekf_m.cpu())
        all_x_hat_ukf_m_cpu.append(full_x_hat_ukf_m.cpu()); all_P_hat_ukf_m_cpu.append(full_P_hat_ukf_m.cpu())
        all_x_hat_akf_mdm_m_cpu.append(full_x_hat_akf_mdm_m.cpu()); all_P_hat_akf_mdm_m_cpu.append(full_P_hat_akf_mdm_m.cpu())
        all_x_hat_akf_mehra_m_cpu.append(full_x_hat_akf_mehra_m.cpu())
        
        all_x_hat_kf_ideal_cpu.append(full_x_hat_kf_ideal.cpu()); all_P_hat_kf_ideal_cpu.append(full_P_hat_kf_ideal.cpu())

        print(f"Dokončena trajektorie {i + 1}/{NUM_TEST_TRAJ}...")

# ==============================================================================
# 5. FINÁLNÍ VÝPOČET A VÝPIS METRIK
# ==============================================================================
mse_bkn, anees_bkn = [], []; mse_knetR, anees_knetR = [], []
mse_kf_m, anees_kf_m = [], []
mse_ekf_m, anees_ekf_m = [], []
mse_ukf_m, anees_ukf_m = [], []
mse_akf_mdm_m, anees_akf_mdm_m = [], []
mse_akf_mehra_m = [] 
mse_kf_ideal, anees_kf_ideal = [], []

print("\nPočítám finální metriky pro jednotlivé trajektorie...")

with torch.no_grad():
    for i in range(NUM_TEST_TRAJ):
        x_true = all_x_true_cpu[i]
        
        def get_metrics(x_hat, P_hat):
            mse = F.mse_loss(x_hat[1:], x_true[1:]).item()
            anees = utils.calculate_anees_vectorized(x_true.unsqueeze(0), x_hat.unsqueeze(0), P_hat.unsqueeze(0))
            return mse, anees

        # Data-driven
        mse, anees = get_metrics(all_x_hat_bkn_cpu[i], all_P_hat_bkn_cpu[i]); mse_bkn.append(mse); anees_bkn.append(anees)
        mse, anees = get_metrics(all_x_hat_knetR_cpu[i], all_P_hat_knetR_cpu[i]); mse_knetR.append(mse); anees_knetR.append(anees)
        
        # Mismatched model-based
        mse, anees = get_metrics(all_x_hat_kf_m_cpu[i], all_P_hat_kf_m_cpu[i]); mse_kf_m.append(mse); anees_kf_m.append(anees)
        mse, anees = get_metrics(all_x_hat_ekf_m_cpu[i], all_P_hat_ekf_m_cpu[i]); mse_ekf_m.append(mse); anees_ekf_m.append(anees)
        mse, anees = get_metrics(all_x_hat_ukf_m_cpu[i], all_P_hat_ukf_m_cpu[i]); mse_ukf_m.append(mse); anees_ukf_m.append(anees)
        
        # Mismatched Adaptive
        mse, anees = get_metrics(all_x_hat_akf_mdm_m_cpu[i], all_P_hat_akf_mdm_m_cpu[i]); mse_akf_mdm_m.append(mse); anees_akf_mdm_m.append(anees)
        mse_akf_mehra_m.append(F.mse_loss(all_x_hat_akf_mehra_m_cpu[i][1:], x_true[1:]).item())
        
        # Benchmark ideal
        mse, anees = get_metrics(all_x_hat_kf_ideal_cpu[i], all_P_hat_kf_ideal_cpu[i]); mse_kf_ideal.append(mse); anees_kf_ideal.append(anees)

def avg(metric_list): return np.mean([m for m in metric_list if not np.isnan(m)])
state_dim_for_nees = all_x_true_cpu[0].shape[1]

# --- Finální výpis tabulky ---
print("\n" + "="*85)
print(f"FINÁLNÍ VÝSLEDKY: MODEL MISMATCH SCÉNÁŘ (průměr přes {NUM_TEST_TRAJ} běhů)")
print("Filtrům byla dodána chybná rotace F_model a chybný šum Q_model.")
print("="*85)
print(f"{'Model':<35} | {'Průměrné MSE':<20} | {'Průměrný ANEES':<20}")
print("-" * 85)
print(f"{'--- AI Filtry (Trénováno na chybě) ---':<35} | {'(nižší je lepší)':<20} | {'(bližší ' + str(float(state_dim_for_nees)) + ' je lepší)':<20}")
print(f"{'Bayesian KNet (BKN)':<35} | {avg(mse_bkn):<20.4f} | {avg(anees_bkn):<20.4f}")
print(f"{'KNet with Known R (KNetR)':<35} | {avg(mse_knetR):<20.4f} | {avg(anees_knetR):<20.4f}")
print("-" * 85)
print(f"{'--- Klasické Filtry (Chybný model) ---':<35} | {'':<20} | {'':<20}")
print(f"{'KF (Nepřesný model)':<35} | {avg(mse_kf_m):<20.4f} | {avg(anees_kf_m):<20.4f}")
print(f"{'EKF (Nepřesný model)':<35} | {avg(mse_ekf_m):<20.4f} | {avg(anees_ekf_m):<20.4f}")
print(f"{'UKF (Nepřesný model)':<35} | {avg(mse_ukf_m):<20.4f} | {avg(anees_ukf_m):<20.4f}")
print(f"{'AKF-MDM (Nepřesný model)':<35} | {avg(mse_akf_mdm_m):<20.4f} | {avg(anees_akf_mdm_m):<20.4f}")
print(f"{'AKF-Mehra (Nepřesný model)':<35} | {avg(mse_akf_mehra_m):<20.4f} | {'N/A':<20}")
print("-" * 85)
print(f"{'--- BENCHMARK (Fyzikální limit) ---':<35} | {'':<20} | {'':<20}")
print(f"{'KF (Ideální model - OPTIMUM)':<35} | {avg(mse_kf_ideal):<20.4f} | {avg(anees_kf_ideal):<20.4f}")
print("="*85)
# Out:
# INFO: Všechny natrénované modely nalezeny a přiřazeny.
#
# Generuji 2 testovacích trajektorií o délce 500...
# Generování dat dokončeno.
#
# Generuji 1 trajektorii o délce 535000 pro offline identifikaci...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 46
#      42 # ==============================================================================
#      43 # 2.B PŘÍPRAVA OFFLINE DAT A PŘEDTRÉNOVÁNÍ ADAPTIVNÍCH FILTRŮ (MISMATCH SCENARIO)
#      44 # ==============================================================================
#      45 print(f"\nGeneruji 1 trajektorii o délce {OFFLINE_SEQ_LEN} pro offline identifikaci...")
# ---> 46 _, y_offline = utils.generate_data(sys_true, num_trajectories=1, seq_len=OFFLINE_SEQ_LEN)
#      47 y_offline_gpu = y_offline.squeeze(0).to(device)
#      49 # Adaptivní filtry dostávají do vínku NEPŘESNÝ model (sys_model), ale data z reálného světa
#
# File ~/skola/KalmanNet-main/utils/utils.py:120, in generate_data(system, num_trajectories, seq_len)
#     117         y_k = system.measure(x_k)
#     119         x_data[:, t, :] = x_k
# --> 120         y_data[:, t, :] = y_k
#     122 return x_data, y_data
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn.functional as F
import numpy as np
from torch.utils.data import TensorDataset, DataLoader
import Filters
from copy import deepcopy  # <-- ZÁSADNÍ IMPORT
from utils import utils

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ==============================================================================
# 0. PŘEDPOKLADY - ZDE PŘIŘAĎTE VAŠE NATRÉNOVANÉ MODELY
# ==============================================================================
# POZNÁMKA: Sítě trained_model_bkn a trained_model_knetR musí být inicializovány 
# s objektem `sys_model` (chybná dynamika) před spuštěním tohoto skriptu!
try:
    trained_model_bkn = trained_model
    trained_model_knetR = state_knetR
    print("INFO: Všechny natrénované modely nalezeny a přiřazeny.")
except NameError:
    print("VAROVÁNÍ: Některé z proměnných `trained_model`, nebo `state_knetR` nebyly nalezeny.")
    print("         Ujistěte se, že jste nejprve úspěšně dokončili trénink všech modelů.")

# ==============================================================================
# 1. KONFIGURACE TESTU
# ==============================================================================
# POZOR: Nastaveno na 200, aby odpovídalo délce tréninku a síť nešla do OOD
TEST_SEQ_LEN = 500 
NUM_TEST_TRAJ = 50
J_SAMPLES_TEST = 50
# Délka odpovídající trénovací + validační sadě (10*500 + 20*200) pro adaptivní metody
OFFLINE_SEQ_LEN = 9000

# ==============================================================================
# 2. PŘÍPRAVA DAT (Generováno z ideálního / skutečného světa)
# ==============================================================================
print(f"\nGeneruji {NUM_TEST_TRAJ} testovacích trajektorií o délce {TEST_SEQ_LEN}...")
# Data generujeme VŽDY pomocí sys_true (skutečná fyzika)
x_test, y_test = utils.generate_data(sys_true, num_trajectories=NUM_TEST_TRAJ, seq_len=TEST_SEQ_LEN)
test_dataset = TensorDataset(x_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
print("Generování testovacích dat dokončeno.")

# ==============================================================================
# 3. PŘÍPRAVA OFFLINE DAT A PŘEDTRÉNOVÁNÍ ADAPTIVNÍCH FILTRŮ (MISMATCH SCENARIO)
# ==============================================================================
print(f"\nGeneruji 1 trajektorii o délce {OFFLINE_SEQ_LEN} pro offline identifikaci...")
x_offline, y_offline = utils.generate_data(sys_true, num_trajectories=1, seq_len=OFFLINE_SEQ_LEN)
y_offline_gpu = y_offline.squeeze(0).to(device) 
x_offline_gpu = x_offline.squeeze(0).to(device)

# Skutečný počátek offline trajektorie pro fér předtrénování
offline_Ex0 = x_offline_gpu[0, :]

# Adaptivní filtry dostávají do vínku NEPŘESNÝ model (sys_model), ale data z reálného světa
akf_mdm_mismatched = Filters.AdaptiveKalmanFilter(deepcopy(sys_model), mdm_L=6, mdm_version=2)
# U Mehry používáme upravenou třídu s dávkováním (batch_size) a omezením pohledu do zrotované minulosti (max_lags)
akf_mehra_mismatched = Filters.AdaptiveKalmanFilter_mehra_offline_pretraining(
    deepcopy(sys_model), 
    num_iterations=50,
    batch_size=500,
    max_lags=2
)

print("\nSpouštím offline identifikaci Q a R (MDM) pro nepřesný model...")
Q_est_mdm_m, R_est_mdm_m = akf_mdm_mismatched.estimate_qr_from_data(y_offline_gpu)

print("\nSpouštím offline identifikaci ustáleného zisku K (Mehra) pro nepřesný model...")
# Předáváme celou x_true_seq kvůli dávkování
K_est_mehra_m = akf_mehra_mismatched.estimate_K_from_data(y_offline_gpu, x_true_seq=x_offline_gpu)

print("\nOffline identifikace MISMATCH modelů dokončena.")

# ==============================================================================
# 4. INICIALIZACE STATICKÝCH FILTRŮ (TEST NA NEPŘESNÉM MODELU)
# ==============================================================================
# Každý filtr dostane svou vlastní odizolovanou kopii systému
kf_mismatched = Filters.KalmanFilter(deepcopy(sys_model))
ekf_mismatched = Filters.ExtendedKalmanFilter(deepcopy(sys_model))
ukf_mismatched = Filters.UnscentedKalmanFilter(deepcopy(sys_model))

# Ponecháme si jeden čistě ideální KF jako referenci (Spodní mez chyby)
kf_ideal = Filters.KalmanFilter(deepcopy(sys_true))

print("\nStatické filtry inicializovány s oddělenými kopiemi NEPŘESNÉHO modelu (sys_model).")
print("Ideální KF inicializován s PŘESNÝM modelem (sys_true) jako benchmark.")

# ==============================================================================
# 5. VYHODNOCOVACÍ SMYČKA
# ==============================================================================
all_x_true_cpu = []
all_x_hat_bkn_cpu, all_P_hat_bkn_cpu = [], []
all_x_hat_knetR_cpu, all_P_hat_knetR_cpu = [], []
all_x_hat_kf_m_cpu, all_P_hat_kf_m_cpu = [], []
all_x_hat_ekf_m_cpu, all_P_hat_ekf_m_cpu = [], []
all_x_hat_ukf_m_cpu, all_P_hat_ukf_m_cpu = [], []
all_x_hat_akf_mdm_m_cpu, all_P_hat_akf_mdm_m_cpu = [], []
all_x_hat_akf_mehra_m_cpu = [] 
all_x_hat_kf_ideal_cpu, all_P_hat_kf_ideal_cpu = [], []

print(f"\nVyhodnocuji modely na {NUM_TEST_TRAJ} testovacích trajektoriích...")

trained_model_bkn.eval() 
trained_model_knetR.eval()

with torch.no_grad():
    for i, (x_true_seq_batch, y_test_seq_batch) in enumerate(test_loader):
        y_test_seq_gpu = y_test_seq_batch.squeeze(0).to(device)
        x_true_seq_gpu = x_true_seq_batch.squeeze(0).to(device)
        initial_state = x_true_seq_gpu[0, :] # OPRAVA pro fer start (použito pro Ex0 u KF filtrů)
        initial_state_unsqueezed = initial_state.unsqueeze(0) # Pro neuronky (potřebují batch dim)
        
        # --- A. Bayesian KalmanNet (Trajectory-wise) ---
        ensemble_trajectories = []
        for j in range(J_SAMPLES_TEST):
            trained_model_bkn.reset(batch_size=1, initial_state=initial_state_unsqueezed)
            current_x_hats = []
            for t in range(1, TEST_SEQ_LEN):
                x_filtered_t, _ = trained_model_bkn.step(y_test_seq_gpu[t, :].unsqueeze(0))
                current_x_hats.append(x_filtered_t)
            ensemble_trajectories.append(torch.cat(current_x_hats, dim=0))
        ensemble = torch.stack(ensemble_trajectories, dim=0)
        predictions_bkn = ensemble.mean(dim=0)
        diff = ensemble - predictions_bkn.unsqueeze(0)
        covariances_bkn = (diff.unsqueeze(-1) @ diff.unsqueeze(-2)).mean(dim=0)
        full_x_hat_bkn = torch.cat([initial_state_unsqueezed, predictions_bkn], dim=0)
        # P0 zůstává chybné (z modelu)
        full_P_hat_bkn = torch.cat([sys_model.P0.unsqueeze(0), covariances_bkn], dim=0)

        # --- B. StateKalmanNetWithKnownR ---
        trained_model_knetR.reset(batch_size=1, initial_state=initial_state_unsqueezed)
        knetR_preds_x, knetR_preds_P = [], []
        for t in range(1, TEST_SEQ_LEN):
            x_filtered_t, P_filtered_t = trained_model_knetR.step(y_test_seq_gpu[t, :].unsqueeze(0))
            knetR_preds_x.append(x_filtered_t)
            knetR_preds_P.append(P_filtered_t)
        full_x_hat_knetR = torch.cat([initial_state_unsqueezed, torch.cat(knetR_preds_x, dim=0)], dim=0)
        
        processed_P_list = []
        for p_tensor in knetR_preds_P:
            while p_tensor.dim() < 2: p_tensor = p_tensor.unsqueeze(-1)
            if p_tensor.dim() > 2 and p_tensor.shape[0] == 1: p_tensor = p_tensor.squeeze(0)
            processed_P_list.append(p_tensor)

        P_sequence_knetR = torch.stack(processed_P_list, dim=0)
        P0_for_cat = sys_model.P0.clone()
        while P0_for_cat.dim() < P_sequence_knetR.dim(): P0_for_cat = P0_for_cat.unsqueeze(0)
        full_P_hat_knetR = torch.cat([P0_for_cat, P_sequence_knetR], dim=0)

        # --- C. Klasické filtry (MISMATCHED) ---
        # OPRAVA: Ex0 nahrazeno za initial_state
        kf_m_res = kf_mismatched.process_sequence(y_test_seq_gpu, Ex0=initial_state, P0=sys_model.P0)
        full_x_hat_kf_m = kf_m_res['x_filtered']
        full_P_hat_kf_m = kf_m_res['P_filtered']
        
        ekf_m_res = ekf_mismatched.process_sequence(y_test_seq_gpu, Ex0=initial_state, P0=sys_model.P0)
        full_x_hat_ekf_m = ekf_m_res['x_filtered']
        full_P_hat_ekf_m = ekf_m_res['P_filtered']
        
        ukf_m_res = ukf_mismatched.process_sequence(y_test_seq_gpu, Ex0=initial_state, P0=sys_model.P0)
        full_x_hat_ukf_m = ukf_m_res['x_filtered']
        full_P_hat_ukf_m = ukf_m_res['P_filtered']

        # --- D. Adaptivní filtry (Inference s naučenými daty na chybném modelu) ---
        # OPRAVA: Ex0 nahrazeno za initial_state
        afk_mdm_m_res = akf_mdm_mismatched.process_sequence_with_qr(
            y_test_seq_gpu, 
            Q_est_mdm_m, 
            R_est_mdm_m, 
            Ex0=initial_state, 
            P0=sys_model.P0
        )
        full_x_hat_akf_mdm_m = afk_mdm_m_res['x_filtered']
        full_P_hat_akf_mdm_m = afk_mdm_m_res['P_filtered'] 

        akf_mehra_m_res = akf_mehra_mismatched.process_sequence_with_K(
            y_test_seq_gpu, 
            K_fixed=K_est_mehra_m, 
            Ex0=initial_state
        )
        full_x_hat_akf_mehra_m = akf_mehra_m_res['x_filtered']   

        # --- E. Benchmark (IDEAL) ---
        # OPRAVA: Ex0 nahrazeno za initial_state (Pro benchmark používáme ideální P0 z reality)
        kf_i_res = kf_ideal.process_sequence(y_test_seq_gpu, Ex0=initial_state, P0=sys_true.P0)
        full_x_hat_kf_ideal = kf_i_res['x_filtered']
        full_P_hat_kf_ideal = kf_i_res['P_filtered']
        
        # Ukládání na CPU
        all_x_true_cpu.append(x_true_seq_gpu.cpu())
        all_x_hat_bkn_cpu.append(full_x_hat_bkn.cpu()); all_P_hat_bkn_cpu.append(full_P_hat_bkn.cpu())
        all_x_hat_knetR_cpu.append(full_x_hat_knetR.cpu()); all_P_hat_knetR_cpu.append(full_P_hat_knetR.cpu())
        
        all_x_hat_kf_m_cpu.append(full_x_hat_kf_m.cpu()); all_P_hat_kf_m_cpu.append(full_P_hat_kf_m.cpu())
        all_x_hat_ekf_m_cpu.append(full_x_hat_ekf_m.cpu()); all_P_hat_ekf_m_cpu.append(full_P_hat_ekf_m.cpu())
        all_x_hat_ukf_m_cpu.append(full_x_hat_ukf_m.cpu()); all_P_hat_ukf_m_cpu.append(full_P_hat_ukf_m.cpu())
        all_x_hat_akf_mdm_m_cpu.append(full_x_hat_akf_mdm_m.cpu()); all_P_hat_akf_mdm_m_cpu.append(full_P_hat_akf_mdm_m.cpu())
        all_x_hat_akf_mehra_m_cpu.append(full_x_hat_akf_mehra_m.cpu())
        
        all_x_hat_kf_ideal_cpu.append(full_x_hat_kf_ideal.cpu()); all_P_hat_kf_ideal_cpu.append(full_P_hat_kf_ideal.cpu())

        print(f"Dokončena trajektorie {i + 1}/{NUM_TEST_TRAJ}...")

# ==============================================================================
# 6. FINÁLNÍ VÝPOČET A VÝPIS METRIK
# ==============================================================================
mse_bkn, anees_bkn = [], []; mse_knetR, anees_knetR = [], []
mse_kf_m, anees_kf_m = [], []
mse_ekf_m, anees_ekf_m = [], []
mse_ukf_m, anees_ukf_m = [], []
mse_akf_mdm_m, anees_akf_mdm_m = [], []
mse_akf_mehra_m = [] 
mse_kf_ideal, anees_kf_ideal = [], []

print("\nPočítám finální metriky pro jednotlivé trajektorie...")

with torch.no_grad():
    for i in range(NUM_TEST_TRAJ):
        x_true = all_x_true_cpu[i]
        
        def get_metrics(x_hat, P_hat):
            mse = F.mse_loss(x_hat[1:], x_true[1:]).item()
            anees = utils.calculate_anees_vectorized(x_true.unsqueeze(0), x_hat.unsqueeze(0), P_hat.unsqueeze(0))
            return mse, anees

        # Data-driven
        mse, anees = get_metrics(all_x_hat_bkn_cpu[i], all_P_hat_bkn_cpu[i]); mse_bkn.append(mse); anees_bkn.append(anees)
        mse, anees = get_metrics(all_x_hat_knetR_cpu[i], all_P_hat_knetR_cpu[i]); mse_knetR.append(mse); anees_knetR.append(anees)
        
        # Mismatched model-based
        mse, anees = get_metrics(all_x_hat_kf_m_cpu[i], all_P_hat_kf_m_cpu[i]); mse_kf_m.append(mse); anees_kf_m.append(anees)
        mse, anees = get_metrics(all_x_hat_ekf_m_cpu[i], all_P_hat_ekf_m_cpu[i]); mse_ekf_m.append(mse); anees_ekf_m.append(anees)
        mse, anees = get_metrics(all_x_hat_ukf_m_cpu[i], all_P_hat_ukf_m_cpu[i]); mse_ukf_m.append(mse); anees_ukf_m.append(anees)
        
        # Mismatched Adaptive
        mse, anees = get_metrics(all_x_hat_akf_mdm_m_cpu[i], all_P_hat_akf_mdm_m_cpu[i]); mse_akf_mdm_m.append(mse); anees_akf_mdm_m.append(anees)
        mse_akf_mehra_m.append(F.mse_loss(all_x_hat_akf_mehra_m_cpu[i][1:], x_true[1:]).item())
        
        # Benchmark ideal
        mse, anees = get_metrics(all_x_hat_kf_ideal_cpu[i], all_P_hat_kf_ideal_cpu[i]); mse_kf_ideal.append(mse); anees_kf_ideal.append(anees)

def avg(metric_list): return np.mean([m for m in metric_list if not np.isnan(m)])
state_dim_for_nees = all_x_true_cpu[0].shape[1]

# --- Finální výpis tabulky ---
print("\n" + "="*85)
print(f"FINÁLNÍ VÝSLEDKY: MODEL MISMATCH SCÉNÁŘ (průměr přes {NUM_TEST_TRAJ} běhů)")
print("Filtrům byla dodána chybná rotace F_model a chybný šum Q_model.")
print("="*85)
print(f"{'Model':<35} | {'Průměrné MSE':<20} | {'Průměrný ANEES':<20}")
print("-" * 85)
print(f"{'--- AI Filtry (Trénováno na chybě) ---':<35} | {'(nižší je lepší)':<20} | {'(bližší ' + str(float(state_dim_for_nees)) + ' je lepší)':<20}")
print(f"{'Bayesian KNet (BKN)':<35} | {avg(mse_bkn):<20.4f} | {avg(anees_bkn):<20.4f}")
print(f"{'KNet with Known R (KNetR)':<35} | {avg(mse_knetR):<20.4f} | {avg(anees_knetR):<20.4f}")
print("-" * 85)
print(f"{'--- Klasické Filtry (Chybný model) ---':<35} | {'':<20} | {'':<20}")
print(f"{'KF (Nepřesný model)':<35} | {avg(mse_kf_m):<20.4f} | {avg(anees_kf_m):<20.4f}")
print(f"{'EKF (Nepřesný model)':<35} | {avg(mse_ekf_m):<20.4f} | {avg(anees_ekf_m):<20.4f}")
print(f"{'UKF (Nepřesný model)':<35} | {avg(mse_ukf_m):<20.4f} | {avg(anees_ukf_m):<20.4f}")
print(f"{'AKF-MDM (Nepřesný model)':<35} | {avg(mse_akf_mdm_m):<20.4f} | {avg(anees_akf_mdm_m):<20.4f}")
print(f"{'AKF-Mehra (Nepřesný model)':<35} | {avg(mse_akf_mehra_m):<20.4f} | {'N/A':<20}")
print("-" * 85)
print(f"{'--- BENCHMARK (Fyzikální limit) ---':<35} | {'':<20} | {'':<20}")
print(f"{'KF (Ideální model - OPTIMUM)':<35} | {avg(mse_kf_ideal):<20.4f} | {avg(anees_kf_ideal):<20.4f}")
print("="*85)

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

print("Generuji graf 3-sigma hranic spolehlivosti pro MISMATCH (3 modely)...")

# Globální nastavení pro akademický vzhled (fonty podobné LaTeXu)
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 12,
    'axes.labelsize': 14,
    'legend.fontsize': 11,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'lines.linewidth': 1.5
})

# Funkce pro bezpečné uložení do PDF (podporuje průhlednost)
def save_plot_pdf(filename, folder_name="LinearSystemMismatchGraphs"):
    os.makedirs(folder_name, exist_ok=True)
    filepath = os.path.join(folder_name, f"{filename}.pdf")
    plt.savefig(filepath, format='pdf', bbox_inches='tight')
    print(f"--> Graf uložen jako: {filepath}")

# Vezmeme první trajektorii z předchozího testování
traj_idx = 0

# Omezení délky vykreslení pro přehlednost (např. prvních 100 kroků)
plot_len = 100 
time_steps = np.arange(plot_len)

# Skutečný stav (1. dimenze)
x_true = all_x_true_cpu[traj_idx][:plot_len, 0].numpy()

# ==============================================================================
# EXTRAKCE DAT - MISMATCHED KF (Chybný model)
# ==============================================================================
x_hat_kf_m = all_x_hat_kf_m_cpu[traj_idx][:plot_len, 0].numpy()
P_kf_m = all_P_hat_kf_m_cpu[traj_idx][:plot_len, 0, 0].numpy() 
error_kf_m = x_hat_kf_m - x_true
std_kf_m = np.sqrt(P_kf_m)

# ==============================================================================
# EXTRAKCE DAT - IDEAL KF (Chybný model)
# ==============================================================================
x_hat_kf_i = all_x_hat_kf_ideal_cpu[traj_idx][:plot_len, 0].numpy()
P_kf_i = all_P_hat_kf_ideal_cpu[traj_idx][:plot_len, 0, 0].numpy() 
error_kf_i = x_hat_kf_i - x_true
std_kf_i = np.sqrt(P_kf_i)

# ==============================================================================
# EXTRAKCE DAT - KALMANNET (KNetR)
# ==============================================================================
# Zde se objeví RuntimeWarning kvůli zápornému P, což je v pořádku a očekávané!
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    x_hat_knet = all_x_hat_knetR_cpu[traj_idx][:plot_len, 0].numpy()
    P_knet = all_P_hat_knetR_cpu[traj_idx][:plot_len, 0, 0].numpy() 
    error_knet = x_hat_knet - x_true
    std_knet = np.sqrt(P_knet)

# ==============================================================================
# EXTRAKCE DAT - BAYESIAN KNET (BKN)
# ==============================================================================
x_hat_bkn = all_x_hat_bkn_cpu[traj_idx][:plot_len, 0].numpy()
P_bkn = all_P_hat_bkn_cpu[traj_idx][:plot_len, 0, 0].numpy() 
error_bkn = x_hat_bkn - x_true
std_bkn = np.sqrt(P_bkn)

# ==============================================================================
# VYKRESLENÍ
# ==============================================================================
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10, 9), sharex=True, sharey=True)

# Společný limit pro osu Y, aby šlo grafy porovnávat (Mismatched KF ustřelí hodně)
y_limit = max(np.max(np.abs(error_kf_m)), np.max(np.abs(error_bkn))) * 2

# --- 1. Graf: Mismatched Kalmanův filtr ---
ax1.plot(time_steps, error_kf_m, label='Chyba odhadu', color='#d62728', linewidth=1.5)
ax1.fill_between(time_steps, 3 * std_kf_m, -3 * std_kf_m, color='#d62728', alpha=0.2, label=r'$\pm 3\sigma$ hranice')
ax1.axhline(0, color='black', linestyle='--', linewidth=1)

ax1.text(0.01, 0.94, '(a) Kalmanův filtr (Nepřesný model)', transform=ax1.transAxes, 
         fontsize=13, fontweight='bold', va='top', 
         bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

ax1.set_ylabel("Chyba pozice X [m]")
ax1.grid(True, linestyle=':', alpha=0.7)
ax1.legend(loc='lower right')
ax1.set_xlim(0, plot_len - 1)
ax1.set_ylim(-y_limit, y_limit)

# --- 2. Graf: Klasický KalmanNet ---
ax2.plot(time_steps, error_knet, label='Chyba odhadu', color='#ff7f0e', linewidth=1.5)
# Používáme where podmínku, aby fill_between nehavarovalo na NaN
valid_knet = ~np.isnan(std_knet)
ax2.fill_between(time_steps, 3 * std_knet, -3 * std_knet, where=valid_knet, color='#ff7f0e', alpha=0.2, label=r'$\pm 3\sigma$ hranice')
ax2.axhline(0, color='black', linestyle='--', linewidth=1)

ax2.text(0.01, 0.94, '(b) KalmanNet', transform=ax2.transAxes, 
         fontsize=13, fontweight='bold', va='top', 
         bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

ax2.set_ylabel("Chyba pozice X [m]")
ax2.grid(True, linestyle=':', alpha=0.7)
ax2.legend(loc='lower right')
ax2.set_xlim(0, plot_len - 1)
ax2.set_ylim(-y_limit, y_limit)

# --- 3. Graf: Bayesian KalmanNet ---
ax3.plot(time_steps, error_bkn, label='Chyba odhadu', color='#1f77b4', linewidth=1.5)
ax3.fill_between(time_steps, 3 * std_bkn, -3 * std_bkn, color='#1f77b4', alpha=0.2, label=r'$\pm 3\sigma$ hranice')
ax3.axhline(0, color='black', linestyle='--', linewidth=1)

ax3.text(0.01, 0.94, '(c) Bayesian KalmanNet', transform=ax3.transAxes, 
         fontsize=13, fontweight='bold', va='top', 
         bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

ax3.set_ylabel("Chyba pozice X [m]")
ax3.set_xlabel("Časový krok [k]")
ax3.grid(True, linestyle=':', alpha=0.7)
ax3.legend(loc='lower right')
ax3.set_xlim(0, plot_len - 1)
ax3.set_ylim(-y_limit, y_limit)

plt.tight_layout()
save_plot_pdf("Uncertainty_mismatch_detail")
plt.show()

# Výpis průměrných hodnot (ignorujeme NaN)
print(f"Průměrná hodnota +- 3 sigma (Mismatched KF): {np.nanmean(3 * std_kf_m):.4f}")
print(f"Průměrná hodnota +- 3 sigma (KNet):           {np.nanmean(3 * std_knet):.4f}")
print(f"Průměrná hodnota +- 3 sigma (BKN):            {np.nanmean(3 * std_bkn):.4f}")

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==============================================================================
# VYKRESLENÍ TRAJEKTORIE V ČASE (Výřez pro přehlednost)
# ==============================================================================
print("Generuji akademický graf odhadu trajektorie v čase...")

# Globální nastavení pro akademický vzhled (fonty podobné LaTeXu)
plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 12,
    'axes.labelsize': 14,
    'legend.fontsize': 11,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'lines.linewidth': 1.5
})

# Vybereme první trajektorii k vykreslení
traj_idx = 0

# Nastavení výřezu (krok 100 až 200) pro lepší viditelnost detailů
start_idx = 100
end_idx = 200
time_steps = np.arange(start_idx, end_idx)

# Extrakce dat pro 1. stavovou proměnnou (Poloha X) z uložených tenzorů
x_true = all_x_true_cpu[traj_idx][start_idx:end_idx, 0].numpy()
y_meas = y_test[traj_idx, start_idx:end_idx, 0].cpu().numpy()
x_hat_kf = all_x_hat_kf_m_cpu[traj_idx][start_idx:end_idx, 0].numpy()
x_hat_knetR = all_x_hat_knetR_cpu[traj_idx][start_idx:end_idx, 0].numpy()
x_hat_bkn = all_x_hat_bkn_cpu[traj_idx][start_idx:end_idx, 0].numpy()

# ==============================================================================
# VYKRESLENÍ GRAFU
# ==============================================================================
fig = plt.figure(figsize=(12, 5)) # Upravený poměr stran pro lepší vzhled na A4

# 1. Hrubé měření (světle šedé křížky na pozadí)
plt.plot(time_steps, y_meas, 'x', color='darkgray', alpha=0.6, markersize=5, label='Senzor (Měření)')

# 2. Skutečný stav (tlustá poloprůhledná světle šedá čára na pozadí)
plt.plot(time_steps, x_true, color='silver', linewidth=6, alpha=0.7, label='Skutečný stav')

# 3. KNet (červená, čárkovaná)
plt.plot(time_steps, x_hat_knetR, color='#d62728', linewidth=1.8, linestyle='--', label='KNet (Známé R)')

# 4. Bayesian KNet (modrá, čerchovaná pro odlišení od KNetu)
plt.plot(time_steps, x_hat_bkn, color='#1f77b4', linewidth=1.8, linestyle='-.', label='Bayesian KNet (BKN)')

# 5. Ideální KF (černá, tečkovaná - kreslíme jako poslední, aby byla úplně nahoře)
plt.plot(time_steps, x_hat_kf, color='black', linewidth=1.5, linestyle=':', label='KF (nepřesný model)')

plt.plot(time_steps, error_kf_i, label='KF (ideální model)', color='#2ca02c', linestyle='-.', linewidth=1.5, alpha=0.8, zorder=1)

plt.xlabel('Časový krok [k]')
plt.ylabel('Stavová proměnná (Poloha X) [m]')

# Zjemnění mřížky
plt.grid(True, linestyle=':', alpha=0.7)

# Oříznutí osy X přesně na okraje dat
plt.xlim(start_idx, end_idx - 1)

# Přesun legendy úplně mimo graf nahoru (do 3 sloupců) a odstranění jejího rámečku
plt.legend(loc='lower center', bbox_to_anchor=(0.5, 1.02), ncol=3, frameon=False)

plt.tight_layout()
save_plot_eps("Trajectory_comparison_detail")
plt.show()
