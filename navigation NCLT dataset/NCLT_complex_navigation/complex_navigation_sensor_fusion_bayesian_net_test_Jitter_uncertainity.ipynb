# %%
from pathlib import Path
from scipy.io import loadmat
import sys
import os

notebook_path = os.getcwd() 
print (f"Current notebook path: {notebook_path}")
project_root = os.path.dirname(notebook_path)
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print (f"Added {project_root} to sys.path")

# %%
import torch
import matplotlib.pyplot as plt
from utils import trainer
from utils import utils
from Systems import DynamicSystem
import Filters
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
from scipy.io import loadmat
from scipy.interpolate import RegularGridInterpolator
import random

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DEVICE = device  # For backward compatibility
print(f"device: {device}")
# Out:
# device: cuda

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
import os
import Systems


# Parametry sekvencí
TRAIN_SEQ_LEN = 100       # Délka sekvence pro trénink (např. 100 kroků = 100 sekund při 1Hz)
VAL_SEQ_LEN = 250
TEST_SEQ_LEN = 1000      # Délka sekvence pro testování (delší sekvence pro stabilnější vyhodnocení)
STRIDE = 30         # Posun okna (překryv) pro data augmentation
BATCH_SIZE = 128
DATA_PATH = 'data/processed'
print(f"Běží na zařízení: {device}")
# Out:
# Běží na zařízení: cuda

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
import os

def prepare_sequences(dataset_list, seq_len, stride, mode='train'):
    """
    Zpracuje list trajektorií na sekvence pro trénink dle článku.
    
    Nový formát dle [Song et al., 2024]:
    - Vstup u (4D): [v_left, v_right, theta_imu, omega_imu]
    - Cíl x (6D):   [px, py, vx, vy, theta, omega]
    """
    X_seq_list = [] # Ground Truth (Cíl)
    Y_seq_list = [] # GPS Měření (Vstup do korekce)
    U_seq_list = [] # Control Input (IMU/Odo)
    
    print(f"Zpracovávám {len(dataset_list)} trajektorií pro {mode}...")
    
    for traj in dataset_list:
        # 1. Extrahuje data
        # GT z preprocessingu je [px, py, theta]
        gt = traj['ground_truth'].float() 
        
        # GPS: [x, y] (obsahuje NaN!)
        gps = traj['filtered_gps'].float()
        
        # IMU: [ax, ay, theta, omega]
        imu = traj['imu'].float()
        theta_imu = imu[:, 2] # Orientace z IMU
        omega_imu = imu[:, 3] # Úhlová rychlost z IMU
        
        # ODO: [v_left, v_right]
        odo = traj['filtered_wheel'].float()
        
        # Fix NaN v odometrii (nahradíme nulou)
        v_left = torch.nan_to_num(odo[:, 0], nan=0.0)
        v_right = torch.nan_to_num(odo[:, 1], nan=0.0)
        
        # 2. Sestavení vstupu u = [v_l, v_r, theta_imu, omega_imu] (4D)
        # Toto odpovídá "State Model" definovanému v článku (sekce II.C.2)
        u = torch.stack((v_left, v_right, theta_imu, omega_imu), dim=1)
        
        # 3. Sestavení cíle x (6D) pro state vector [px, py, vx, vy, theta, omega]
        # Vyplníme to, co máme z Ground Truth (px, py, theta).
        # Rychlosti (vx, vy, omega) v GT implicitně nemáme (nebo je složité je derivovat přesně),
        # ale pro trénink Loss funkce budeme stejně porovnávat primárně pozici.
        T = gt.shape[0]
        x_target = torch.zeros(T, 6)
        x_target[:, 0] = gt[:, 0] # px
        x_target[:, 1] = gt[:, 1] # py
        x_target[:, 4] = gt[:, 2] # theta
        # Ostatní (vx, vy, omega) zůstávají 0, protože v Loss funkci budeme maskovat nebo brát jen pozici.
        
        # 4. Sliding Window (Rozsekání na sekvence)
        num_samples = gt.shape[0]
        current_stride = stride if mode == 'train' else seq_len # U testu bez překryvu
        
        for i in range(0, num_samples - seq_len + 1, current_stride):
            # Cíl: 6D stav
            x_seq = x_target[i : i+seq_len, :]
            
            # Měření: GPS [px, py]
            y_seq = gps[i : i+seq_len, :]
            
            # Vstup: 4D control input
            u_seq = u[i : i+seq_len, :]
            
            X_seq_list.append(x_seq)
            Y_seq_list.append(y_seq)
            U_seq_list.append(u_seq)
            
    # Stack do tenzorů
    X_out = torch.stack(X_seq_list)
    Y_out = torch.stack(Y_seq_list)
    U_out = torch.stack(U_seq_list)
    
    return X_out, Y_out, U_out

# === NAČTENÍ DAT ===
# Ujistíme se, že cesty a konstanty jsou definované (pokud nejsou, doplňte je nahoře)
# if 'DATA_PATH' not in locals(): DATA_PATH = 'data/processed'
# if 'TRAIN_SEQ_LEN' not in locals(): TRAIN_SEQ_LEN = 100
# if 'VAL_SEQ_LEN' not in locals(): VAL_SEQ_LEN = 200
# if 'TEST_SEQ_LEN' not in locals(): TEST_SEQ_LEN = 500
# if 'STRIDE' not in locals(): STRIDE = 20
# if 'BATCH_SIZE' not in locals(): BATCH_SIZE = 256

train_data_raw = torch.load(os.path.join(DATA_PATH, 'train.pt'))
val_data_raw = torch.load(os.path.join(DATA_PATH, 'val.pt'))
test_data_raw = torch.load(os.path.join(DATA_PATH, 'test.pt'))
# Načtení celého balíku
# train_data_full = torch.load(os.path.join(DATA_PATH, 'train.pt'))

# === RYCHLÝ TEST: OŘÍZNUTÍ DAT ===
# Vezmeme jen prvních 5 trajektorií z 22. 
# To radikálně zrychlí jednu epochu a umožní rychle otestovat stabilitu hyperparametrů.
# train_data_raw = train_data_full[:10] 

print(f"DEBUG: Pro rychlý test používám jen {len(train_data_raw)} trajektorií.")
# ... zbytek kódu beze změny

# === PŘÍPRAVA SEKVENCÍ ===
print("--- Generuji trénovací data (Paper compatible) ---")
train_X, train_Y, train_U = prepare_sequences(train_data_raw, TRAIN_SEQ_LEN, STRIDE, 'train')

print("\n--- Generuji validační data ---")
val_X, val_Y, val_U = prepare_sequences(val_data_raw, VAL_SEQ_LEN, VAL_SEQ_LEN, 'val')

print("\n--- Generuji testovací data ---")
test_X, test_Y, test_U = prepare_sequences(test_data_raw, TEST_SEQ_LEN, TEST_SEQ_LEN, 'test')

# Vytvoření DataLoaderů
train_loader = DataLoader(TensorDataset(train_X, train_Y, train_U), batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(TensorDataset(val_X, val_Y, val_U), batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(TensorDataset(test_X, test_Y, test_U), batch_size=BATCH_SIZE, shuffle=False)

print(f"\n✅ Data připravena.")
print(f"Train batches: {len(train_loader)}")
print(f"Shapes -> X: {train_X.shape} (6D State), U: {train_U.shape} (4D Input), Y: {train_Y.shape} (2D Meas)")
# Out:
# DEBUG: Pro rychlý test používám jen 22 trajektorií.
# --- Generuji trénovací data (Paper compatible) ---
# Zpracovávám 22 trajektorií pro train...
#
# --- Generuji validační data ---
# Zpracovávám 2 trajektorií pro val...
#
# --- Generuji testovací data ---
# Zpracovávám 3 trajektorií pro test...
#
# ✅ Data připravena.
# Train batches: 29
# Shapes -> X: torch.Size([3635, 100, 6]) (6D State), U: torch.Size([3635, 100, 4]) (4D Input), Y: torch.Size([3635, 100, 2]) (2D Meas)

# %%
# === INICIALIZACE DYNAMICKÉHO MODELU (System Instance - Paper Version) ===

# 1. Parametry systému podle článku [Song et al., 2024]
# State (6D): [px, py, vx, vy, theta, omega]
# Referenční rovnice (5) v článku.
state_dim = 6
# Meas (2D):  [gps_x, gps_y]
# Referenční rovnice (6) v článku.
obs_dim = 2
# Časový krok (z preprocessingu)
dt = 1.0  

# 2. Definice Matice Q (Procesní šum / Model Uncertainty)
# Nyní máme 6 stavů. Musíme definovat nejistotu pro každý z nich.
# Hodnoty jsou nastaveny heuristicky (lze ladit):
# - Pozice (idx 0,1): 0.1
# - Rychlost (idx 2,3): 0.1
# - Úhel/Omega (idx 4,5): 0.01 (IMU je v NCLT docela přesné, ale driftuje)
q_diag = torch.tensor([0.1, 0.1, 0.1, 0.1, 0.01, 0.01])
Q = torch.diag(q_diag)

# 3. Definice Matice R (Šum měření / Sensor Noise)
# GPS měří jen pozici (px, py).
# Nastavujeme 1.0 m^2. To odpovídá standardní odchylce 1m.
# Pokud je GPS v datasetu horší, KalmanNet se naučí "nedůvěřovat" vstupu y
# a spoléhat více na predikci z u (odometrie).
r_diag = torch.tensor([1.0, 1.0])
R = torch.diag(r_diag)

# 4. Počáteční podmínky (Prior)
# Ex0: Nulový vektor 6x1
Ex0 = torch.zeros(state_dim, 1)

# P0: Počáteční kovariance
# Autoři používají P k inicializaci EKF[cite: 700].
# Nastavíme rozumnou počáteční nejistotu.
P0 = torch.eye(state_dim) * 0.5

# 5. Vytvoření instance DynamicSystemNCLT
# Důležité: f=None zajistí, že se použije interní `_f_paper_dynamics` (rovnice 5),
# která očekává 4D vstup (v_l, v_r, theta, omega).
sys_model = Systems.DynamicSystemNCLT(
    state_dim=state_dim,
    obs_dim=obs_dim,
    Q=Q,
    R=R,
    Ex0=Ex0,
    P0=P0,
    dt=dt,
    f=None,  # None -> Použije se model z článku: px += vc*cos(theta_imu)...
    h=None,  # None -> Použije se GPS model: y = [px, py]
    device=DEVICE
)

print(f"✅ System Model NCLT inicializován (Paper Version).")
print(f" - State Dim: {sys_model.state_dim} [px, py, vx, vy, theta, omega]")
print(f" - Meas Dim:  {sys_model.obs_dim} [gps_x, gps_y]")
print(f" - Input Dim: 4 [v_l, v_r, theta_imu, omega_imu]") # Implicitně v modelu
print(f" - Q Diag: {q_diag.tolist()}")
# Out:
# ✅ System Model NCLT inicializován (Paper Version).
#  - State Dim: 6 [px, py, vx, vy, theta, omega]
#  - Meas Dim:  2 [gps_x, gps_y]
#  - Input Dim: 4 [v_l, v_r, theta_imu, omega_imu]
#  - Q Diag: [0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.009999999776482582, 0.009999999776482582]

# %%
import torch
import torch.optim as optim
import os
from state_NN_models import NCLT
from utils import trainer
JITTER_VECTOR = [
    1.5,   # px: 20 cm nejistota v poloze (prokluz)
    1.5,   # py: 20 cm
    0.5,   # vx: 10 cm/s šum rychlosti
    0.5,   # vy: 10 cm/s
    0.06,  # theta: ~1 stupeň (klíčové pro zatáčení trajektorií!)
    0.02   # omega: malý šum
]
state_knet = NCLT.StateBayesianKalmanNetNCLT_Diagnostic(
    system_model=sys_model,
    device=DEVICE,
    hidden_size_multiplier=10,      # Větší kapacita pro složitější dynamiku
    output_layer_multiplier=4,
    num_gru_layers=1,               # 1 vrstva GRU obvykle stačí a je stabilnější
    init_min_dropout=0.3,
    init_max_dropout=0.4,
    process_jitter=JITTER_VECTOR
).to(DEVICE)
print(state_knet)

# Počet trénovatelných parametrů
params_count = sum(p.numel() for p in state_knet.parameters() if p.requires_grad)
print(f"Model má {params_count} trénovatelných parametrů.")
# === 3. PŘÍPRAVA A SPUŠTĚNÍ TRÉNINKU ===
print("\n🚀 Spouštím tréninkovou smyčku (Vektorizovanou)...")

# 1. Zjistíme velikost datasetu (počet batchů v jedné epoše)
num_train_batches = len(train_loader)
print(f"INFO: 1 Epocha = {num_train_batches} iterací (batchů).")

# 2. Nastavení parametrů
EPOCHS = 100
WARMUP_EPOCHS = 15  # Prvních 15 epoch jen MSE, aby se model stabilizoval

# Přepočet na iterace (protože nová funkce počítá v iteracích)
total_iterations = EPOCHS * num_train_batches
total_iterations = 800
warmup_iterations = WARMUP_EPOCHS * num_train_batches
warmup_iterations=200
validation_period = 5  # Chceme validovat jednou za epochu (na konci)

# 3. Volání funkce
trained_knet = trainer.train_BayesianKalmanNetNCLT_test(
    model=state_knet,
    train_loader=train_loader,
    val_loader=val_loader,
    device=DEVICE,
    
    # Parametry iterací
    total_train_iter=total_iterations,
    learning_rate=1e-4,       # Opatrný LR pro BKN
    clip_grad=0.5,            # Stabilizace gradientů
    J_samples=10,              # Počet MC vzorků (paralelně)
    
    # Logování a validace
    validation_period=validation_period, 
    logging_period=1,        # Výpis loss každých 1 batchu
    
    # Warmup
    warmup_iterations=warmup_iterations,
    weight_decay_=1e-4,
    optimizer_type=torch.optim.AdamW
)
# Out:
# INFO: Aplikuji 'Start Zero' inicializaci pro Kalman Gain.
# DEBUG: Výstupní vrstva vynulována (Soft Start).
# StateBayesianKalmanNetNCLT_Diagnostic(
#   (dnn): DNN_BayesianKalmanNetNCLT_test(
#     (input_layer): Sequential(
#       (0): Linear(in_features=16, out_features=640, bias=True)
#       (1): ReLU()
#     )
#     (concrete_dropout1): ConcreteDropout()
#     (gru): GRU(640, 160)
#     (output_layer): Sequential(
#       (0): Linear(in_features=160, out_features=48, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=48, out_features=12, bias=True)
#     )
#     (concrete_dropout2): ConcreteDropout()
#   )
# )
# Model má 404158 trénovatelných parametrů.
#
# 🚀 Spouštím tréninkovou smyčku (Vektorizovanou)...
# INFO: 1 Epocha = 29 iterací (batchů).
#
# [DIAGNOSTIKA iter 0]
#   -> Rozdíl (Pred - Target): 2.331006
#   -> Min Variance v batchi:  3.62e-05
#   -> Mean Variance v batchi: 3.92e+01
# --- Iteration [1/800] ---
#     - Total Loss: 23.5405
#     - NLL: 3.5546
#     - Reg: 0.2064
#     - p1=0.384, p2=0.302
#
# [DIAGNOSTIKA iter 1]
#   -> Rozdíl (Pred - Target): 2.071721
#   -> Min Variance v batchi:  2.86e-05
#   -> Mean Variance v batchi: 3.86e+01
# --- Iteration [2/800] ---
#     - Total Loss: 18.0745
#     - NLL: 3.2132
#     - Reg: 0.2064
#     - p1=0.384, p2=0.302
#
# [DIAGNOSTIKA iter 2]
#   -> Rozdíl (Pred - Target): 2.109618
#   -> Min Variance v batchi:  6.09e-05
#   -> Mean Variance v batchi: 3.47e+01
# --- Iteration [3/800] ---
#     - Total Loss: 18.2105
#     - NLL: 2.9451
#     - Reg: 0.2064
#     - p1=0.384, p2=0.302
#
# [DIAGNOSTIKA iter 3]
#   -> Rozdíl (Pred - Target): 1.969308
#   -> Min Variance v batchi:  4.45e-05
#   -> Mean Variance v batchi: 3.23e+01
# --- Iteration [4/800] ---
#     - Total Loss: 15.9946
#     - NLL: 3.1995
#     - Reg: 0.2064
#     - p1=0.384, p2=0.302
#
# [DIAGNOSTIKA iter 4]
#   -> Rozdíl (Pred - Target): 1.932110
#   -> Min Variance v batchi:  4.65e-05
#   -> Mean Variance v batchi: 2.83e+01
# --- Iteration [5/800] ---
#     - Total Loss: 14.7334
#     - NLL: 2.8265
#     - Reg: 0.2064
#     - p1=0.384, p2=0.302
#
# --- Validation at iteration 5 ---
#   Average MSE: 32.1164, Average ANEES: 610.0871
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 5]
#   -> Rozdíl (Pred - Target): 1.842188
#   -> Min Variance v batchi:  3.43e-05
#   -> Mean Variance v batchi: 2.62e+01
# --- Iteration [6/800] ---
#     - Total Loss: 13.1501
#     - NLL: 2.4013
#     - Reg: 0.2064
#     - p1=0.384, p2=0.302
#
# [DIAGNOSTIKA iter 6]
#   -> Rozdíl (Pred - Target): 1.690985
#   -> Min Variance v batchi:  2.22e-05
#   -> Mean Variance v batchi: 2.42e+01
# --- Iteration [7/800] ---
#     - Total Loss: 10.9958
#     - NLL: 2.5544
#     - Reg: 0.2064
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 7]
#   -> Rozdíl (Pred - Target): 1.725572
#   -> Min Variance v batchi:  4.86e-05
#   -> Mean Variance v batchi: 2.26e+01
# --- Iteration [8/800] ---
#     - Total Loss: 12.3886
#     - NLL: 2.7173
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 8]
#   -> Rozdíl (Pred - Target): 1.672475
#   -> Min Variance v batchi:  2.82e-05
#   -> Mean Variance v batchi: 2.09e+01
# --- Iteration [9/800] ---
#     - Total Loss: 10.2680
#     - NLL: 2.5488
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 9]
#   -> Rozdíl (Pred - Target): 1.519580
#   -> Min Variance v batchi:  3.17e-05
#   -> Mean Variance v batchi: 1.85e+01
# --- Iteration [10/800] ---
#     - Total Loss: 8.3943
#     - NLL: 2.3993
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 10 ---
#   Average MSE: 22.6882, Average ANEES: 856.3149
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 10]
#   -> Rozdíl (Pred - Target): 1.518236
#   -> Min Variance v batchi:  3.90e-05
#   -> Mean Variance v batchi: 1.63e+01
# --- Iteration [11/800] ---
#     - Total Loss: 9.5218
#     - NLL: 2.1823
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 11]
#   -> Rozdíl (Pred - Target): 1.693134
#   -> Min Variance v batchi:  4.14e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [12/800] ---
#     - Total Loss: 18.2056
#     - NLL: 2.4224
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 12]
#   -> Rozdíl (Pred - Target): 1.432147
#   -> Min Variance v batchi:  6.38e-05
#   -> Mean Variance v batchi: 1.34e+01
# --- Iteration [13/800] ---
#     - Total Loss: 7.3509
#     - NLL: 2.0890
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 13]
#   -> Rozdíl (Pred - Target): 1.430129
#   -> Min Variance v batchi:  6.40e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [14/800] ---
#     - Total Loss: 8.3120
#     - NLL: 2.2077
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 14]
#   -> Rozdíl (Pred - Target): 1.563076
#   -> Min Variance v batchi:  3.69e-05
#   -> Mean Variance v batchi: 1.23e+01
# --- Iteration [15/800] ---
#     - Total Loss: 15.5352
#     - NLL: 2.2104
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 15 ---
#   Average MSE: 21.2266, Average ANEES: 794.4908
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 15]
#   -> Rozdíl (Pred - Target): 1.542720
#   -> Min Variance v batchi:  4.04e-05
#   -> Mean Variance v batchi: 1.27e+01
# --- Iteration [16/800] ---
#     - Total Loss: 9.9242
#     - NLL: 2.2525
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 16]
#   -> Rozdíl (Pred - Target): 1.494051
#   -> Min Variance v batchi:  3.31e-05
#   -> Mean Variance v batchi: 1.24e+01
# --- Iteration [17/800] ---
#     - Total Loss: 11.3728
#     - NLL: 2.1965
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 17]
#   -> Rozdíl (Pred - Target): 1.395693
#   -> Min Variance v batchi:  4.90e-05
#   -> Mean Variance v batchi: 1.24e+01
# --- Iteration [18/800] ---
#     - Total Loss: 7.4848
#     - NLL: 2.0998
#     - Reg: 0.2063
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 18]
#   -> Rozdíl (Pred - Target): 1.272617
#   -> Min Variance v batchi:  2.45e-05
#   -> Mean Variance v batchi: 1.21e+01
# --- Iteration [19/800] ---
#     - Total Loss: 5.3998
#     - NLL: 1.9636
#     - Reg: 0.2062
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 19]
#   -> Rozdíl (Pred - Target): 1.586398
#   -> Min Variance v batchi:  2.30e-05
#   -> Mean Variance v batchi: 1.22e+01
# --- Iteration [20/800] ---
#     - Total Loss: 24.6062
#     - NLL: 2.3149
#     - Reg: 0.2062
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 20 ---
#   Average MSE: 21.3001, Average ANEES: 740.5729
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 20]
#   -> Rozdíl (Pred - Target): 1.523440
#   -> Min Variance v batchi:  3.99e-05
#   -> Mean Variance v batchi: 1.21e+01
# --- Iteration [21/800] ---
#     - Total Loss: 12.8332
#     - NLL: 2.3052
#     - Reg: 0.2062
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 21]
#   -> Rozdíl (Pred - Target): 1.311155
#   -> Min Variance v batchi:  3.77e-05
#   -> Mean Variance v batchi: 1.28e+01
# --- Iteration [22/800] ---
#     - Total Loss: 6.3798
#     - NLL: 2.2762
#     - Reg: 0.2062
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 22]
#   -> Rozdíl (Pred - Target): 1.370451
#   -> Min Variance v batchi:  6.13e-05
#   -> Mean Variance v batchi: 1.18e+01
# --- Iteration [23/800] ---
#     - Total Loss: 9.2531
#     - NLL: 2.0759
#     - Reg: 0.2062
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 23]
#   -> Rozdíl (Pred - Target): 1.316221
#   -> Min Variance v batchi:  4.32e-05
#   -> Mean Variance v batchi: 1.24e+01
# --- Iteration [24/800] ---
#     - Total Loss: 6.6098
#     - NLL: 2.0650
#     - Reg: 0.2061
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 24]
#   -> Rozdíl (Pred - Target): 1.445990
#   -> Min Variance v batchi:  4.42e-05
#   -> Mean Variance v batchi: 1.23e+01
# --- Iteration [25/800] ---
#     - Total Loss: 9.4944
#     - NLL: 2.3274
#     - Reg: 0.2061
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 25 ---
#   Average MSE: 21.1046, Average ANEES: 699.6646
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 25]
#   -> Rozdíl (Pred - Target): 1.430641
#   -> Min Variance v batchi:  4.48e-05
#   -> Mean Variance v batchi: 1.32e+01
# --- Iteration [26/800] ---
#     - Total Loss: 10.0416
#     - NLL: 2.0764
#     - Reg: 0.2061
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 26]
#   -> Rozdíl (Pred - Target): 1.572843
#   -> Min Variance v batchi:  4.42e-05
#   -> Mean Variance v batchi: 1.24e+01
# --- Iteration [27/800] ---
#     - Total Loss: 13.0668
#     - NLL: 2.0877
#     - Reg: 0.2061
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 27]
#   -> Rozdíl (Pred - Target): 1.402987
#   -> Min Variance v batchi:  3.79e-05
#   -> Mean Variance v batchi: 1.21e+01
# --- Iteration [28/800] ---
#     - Total Loss: 8.2249
#     - NLL: 1.9204
#     - Reg: 0.2060
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 28]
#   -> Rozdíl (Pred - Target): 1.294920
#   -> Min Variance v batchi:  5.95e-05
#   -> Mean Variance v batchi: 1.10e+01
# --- Iteration [29/800] ---
#     - Total Loss: 5.9224
#     - NLL: 1.5305
#     - Reg: 0.2060
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 29]
#   -> Rozdíl (Pred - Target): 1.341336
#   -> Min Variance v batchi:  3.86e-05
#   -> Mean Variance v batchi: 1.30e+01
# --- Iteration [30/800] ---
#     - Total Loss: 7.2014
#     - NLL: 2.0077
#     - Reg: 0.2060
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 30 ---
#   Average MSE: 18.0742, Average ANEES: 786.7531
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 30]
#   -> Rozdíl (Pred - Target): 1.399801
#   -> Min Variance v batchi:  4.89e-05
#   -> Mean Variance v batchi: 1.33e+01
# --- Iteration [31/800] ---
#     - Total Loss: 9.1923
#     - NLL: 1.9373
#     - Reg: 0.2060
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 31]
#   -> Rozdíl (Pred - Target): 1.486681
#   -> Min Variance v batchi:  3.36e-05
#   -> Mean Variance v batchi: 1.31e+01
# --- Iteration [32/800] ---
#     - Total Loss: 11.3473
#     - NLL: 2.1228
#     - Reg: 0.2059
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 32]
#   -> Rozdíl (Pred - Target): 1.351990
#   -> Min Variance v batchi:  4.00e-05
#   -> Mean Variance v batchi: 1.37e+01
# --- Iteration [33/800] ---
#     - Total Loss: 7.4322
#     - NLL: 1.8854
#     - Reg: 0.2059
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 33]
#   -> Rozdíl (Pred - Target): 1.395746
#   -> Min Variance v batchi:  4.21e-05
#   -> Mean Variance v batchi: 1.39e+01
# --- Iteration [34/800] ---
#     - Total Loss: 10.1570
#     - NLL: 1.7823
#     - Reg: 0.2059
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 34]
#   -> Rozdíl (Pred - Target): 1.426510
#   -> Min Variance v batchi:  4.37e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [35/800] ---
#     - Total Loss: 9.5540
#     - NLL: 2.0137
#     - Reg: 0.2059
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 35 ---
#   Average MSE: 18.9556, Average ANEES: 700.0989
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 35]
#   -> Rozdíl (Pred - Target): 1.417188
#   -> Min Variance v batchi:  1.70e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [36/800] ---
#     - Total Loss: 8.2615
#     - NLL: 2.0065
#     - Reg: 0.2059
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 36]
#   -> Rozdíl (Pred - Target): 1.326668
#   -> Min Variance v batchi:  5.81e-05
#   -> Mean Variance v batchi: 1.44e+01
# --- Iteration [37/800] ---
#     - Total Loss: 6.5487
#     - NLL: 1.7410
#     - Reg: 0.2058
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 37]
#   -> Rozdíl (Pred - Target): 1.423322
#   -> Min Variance v batchi:  4.02e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [38/800] ---
#     - Total Loss: 9.0658
#     - NLL: 1.9351
#     - Reg: 0.2058
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 38]
#   -> Rozdíl (Pred - Target): 1.311063
#   -> Min Variance v batchi:  2.77e-05
#   -> Mean Variance v batchi: 1.79e+01
# --- Iteration [39/800] ---
#     - Total Loss: 6.6884
#     - NLL: 1.9721
#     - Reg: 0.2058
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 39]
#   -> Rozdíl (Pred - Target): 1.329578
#   -> Min Variance v batchi:  4.24e-05
#   -> Mean Variance v batchi: 1.63e+01
# --- Iteration [40/800] ---
#     - Total Loss: 6.3962
#     - NLL: 1.7008
#     - Reg: 0.2058
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 40 ---
#   Average MSE: 16.7439, Average ANEES: 745.9656
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 40]
#   -> Rozdíl (Pred - Target): 1.373540
#   -> Min Variance v batchi:  5.37e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [41/800] ---
#     - Total Loss: 7.6590
#     - NLL: 1.7791
#     - Reg: 0.2058
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 41]
#   -> Rozdíl (Pred - Target): 1.389468
#   -> Min Variance v batchi:  2.09e-05
#   -> Mean Variance v batchi: 1.58e+01
# --- Iteration [42/800] ---
#     - Total Loss: 8.7344
#     - NLL: 1.9506
#     - Reg: 0.2057
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 42]
#   -> Rozdíl (Pred - Target): 1.345341
#   -> Min Variance v batchi:  4.98e-05
#   -> Mean Variance v batchi: 1.69e+01
# --- Iteration [43/800] ---
#     - Total Loss: 6.5993
#     - NLL: 1.9370
#     - Reg: 0.2057
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 43]
#   -> Rozdíl (Pred - Target): 1.340896
#   -> Min Variance v batchi:  5.11e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [44/800] ---
#     - Total Loss: 6.8123
#     - NLL: 1.7532
#     - Reg: 0.2057
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 44]
#   -> Rozdíl (Pred - Target): 1.553746
#   -> Min Variance v batchi:  5.02e-05
#   -> Mean Variance v batchi: 1.62e+01
# --- Iteration [45/800] ---
#     - Total Loss: 13.1642
#     - NLL: 2.1613
#     - Reg: 0.2057
#     - p1=0.383, p2=0.302
#
# --- Validation at iteration 45 ---
#   Average MSE: 21.2030, Average ANEES: 668.5209
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 45]
#   -> Rozdíl (Pred - Target): 1.337197
#   -> Min Variance v batchi:  4.11e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [46/800] ---
#     - Total Loss: 9.2953
#     - NLL: 1.8096
#     - Reg: 0.2057
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 46]
#   -> Rozdíl (Pred - Target): 1.409381
#   -> Min Variance v batchi:  4.86e-05
#   -> Mean Variance v batchi: 1.37e+01
# --- Iteration [47/800] ---
#     - Total Loss: 8.7988
#     - NLL: 1.8637
#     - Reg: 0.2056
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 47]
#   -> Rozdíl (Pred - Target): 1.381214
#   -> Min Variance v batchi:  4.38e-05
#   -> Mean Variance v batchi: 1.44e+01
# --- Iteration [48/800] ---
#     - Total Loss: 8.1978
#     - NLL: 1.8923
#     - Reg: 0.2056
#     - p1=0.383, p2=0.302
#
# [DIAGNOSTIKA iter 48]
#   -> Rozdíl (Pred - Target): 1.361164
#   -> Min Variance v batchi:  3.44e-05
#   -> Mean Variance v batchi: 1.43e+01
# --- Iteration [49/800] ---
#     - Total Loss: 8.3358
#     - NLL: 1.8713
#     - Reg: 0.2056
#     - p1=0.383, p2=0.301
#
# [DIAGNOSTIKA iter 49]
#   -> Rozdíl (Pred - Target): 1.358745
#   -> Min Variance v batchi:  3.52e-05
#   -> Mean Variance v batchi: 1.60e+01
# --- Iteration [50/800] ---
#     - Total Loss: 6.8853
#     - NLL: 2.0016
#     - Reg: 0.2056
#     - p1=0.383, p2=0.301
#
# --- Validation at iteration 50 ---
#   Average MSE: 18.7919, Average ANEES: 599.4594
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 50]
#   -> Rozdíl (Pred - Target): 1.324291
#   -> Min Variance v batchi:  5.56e-05
#   -> Mean Variance v batchi: 1.42e+01
# --- Iteration [51/800] ---
#     - Total Loss: 7.3968
#     - NLL: 1.9724
#     - Reg: 0.2056
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 51]
#   -> Rozdíl (Pred - Target): 1.425617
#   -> Min Variance v batchi:  2.40e-05
#   -> Mean Variance v batchi: 1.37e+01
# --- Iteration [52/800] ---
#     - Total Loss: 12.1285
#     - NLL: 1.8782
#     - Reg: 0.2055
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 52]
#   -> Rozdíl (Pred - Target): 1.346318
#   -> Min Variance v batchi:  4.12e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [53/800] ---
#     - Total Loss: 7.1878
#     - NLL: 1.7859
#     - Reg: 0.2055
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 53]
#   -> Rozdíl (Pred - Target): 1.313763
#   -> Min Variance v batchi:  2.91e-05
#   -> Mean Variance v batchi: 1.42e+01
# --- Iteration [54/800] ---
#     - Total Loss: 6.6150
#     - NLL: 1.9082
#     - Reg: 0.2055
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 54]
#   -> Rozdíl (Pred - Target): 1.372429
#   -> Min Variance v batchi:  3.66e-05
#   -> Mean Variance v batchi: 1.36e+01
# --- Iteration [55/800] ---
#     - Total Loss: 8.4164
#     - NLL: 2.0911
#     - Reg: 0.2055
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 55 ---
#   Average MSE: 19.0614, Average ANEES: 541.8135
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 55]
#   -> Rozdíl (Pred - Target): 1.346705
#   -> Min Variance v batchi:  3.04e-05
#   -> Mean Variance v batchi: 1.43e+01
# --- Iteration [56/800] ---
#     - Total Loss: 7.9924
#     - NLL: 1.8200
#     - Reg: 0.2055
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 56]
#   -> Rozdíl (Pred - Target): 1.414966
#   -> Min Variance v batchi:  2.81e-05
#   -> Mean Variance v batchi: 1.52e+01
# --- Iteration [57/800] ---
#     - Total Loss: 8.2596
#     - NLL: 2.2703
#     - Reg: 0.2054
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 57]
#   -> Rozdíl (Pred - Target): 1.529821
#   -> Min Variance v batchi:  5.19e-05
#   -> Mean Variance v batchi: 1.43e+01
# --- Iteration [58/800] ---
#     - Total Loss: 12.9321
#     - NLL: 2.3024
#     - Reg: 0.2054
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 58]
#   -> Rozdíl (Pred - Target): 1.323252
#   -> Min Variance v batchi:  6.20e-05
#   -> Mean Variance v batchi: 1.40e+01
# --- Iteration [59/800] ---
#     - Total Loss: 7.4884
#     - NLL: 1.7306
#     - Reg: 0.2054
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 59]
#   -> Rozdíl (Pred - Target): 1.283272
#   -> Min Variance v batchi:  4.33e-05
#   -> Mean Variance v batchi: 1.40e+01
# --- Iteration [60/800] ---
#     - Total Loss: 6.5120
#     - NLL: 1.8413
#     - Reg: 0.2054
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 60 ---
#   Average MSE: 16.7465, Average ANEES: 539.6906
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 60]
#   -> Rozdíl (Pred - Target): 1.315873
#   -> Min Variance v batchi:  4.87e-05
#   -> Mean Variance v batchi: 1.27e+01
# --- Iteration [61/800] ---
#     - Total Loss: 7.2496
#     - NLL: 1.7767
#     - Reg: 0.2054
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 61]
#   -> Rozdíl (Pred - Target): 1.277782
#   -> Min Variance v batchi:  5.03e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [62/800] ---
#     - Total Loss: 6.2838
#     - NLL: 1.7026
#     - Reg: 0.2053
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 62]
#   -> Rozdíl (Pred - Target): 1.329039
#   -> Min Variance v batchi:  4.28e-05
#   -> Mean Variance v batchi: 1.48e+01
# --- Iteration [63/800] ---
#     - Total Loss: 7.4248
#     - NLL: 1.8181
#     - Reg: 0.2053
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 63]
#   -> Rozdíl (Pred - Target): 1.485240
#   -> Min Variance v batchi:  3.96e-05
#   -> Mean Variance v batchi: 1.72e+01
# --- Iteration [64/800] ---
#     - Total Loss: 10.0897
#     - NLL: 2.2815
#     - Reg: 0.2053
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 64]
#   -> Rozdíl (Pred - Target): 1.350769
#   -> Min Variance v batchi:  3.63e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [65/800] ---
#     - Total Loss: 8.0514
#     - NLL: 1.8514
#     - Reg: 0.2053
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 65 ---
#   Average MSE: 20.0515, Average ANEES: 526.0733
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 65]
#   -> Rozdíl (Pred - Target): 1.237366
#   -> Min Variance v batchi:  2.71e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [66/800] ---
#     - Total Loss: 5.4239
#     - NLL: 1.8605
#     - Reg: 0.2053
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 66]
#   -> Rozdíl (Pred - Target): 1.415902
#   -> Min Variance v batchi:  4.36e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [67/800] ---
#     - Total Loss: 8.6302
#     - NLL: 1.9200
#     - Reg: 0.2052
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 67]
#   -> Rozdíl (Pred - Target): 1.288736
#   -> Min Variance v batchi:  4.96e-05
#   -> Mean Variance v batchi: 1.62e+01
# --- Iteration [68/800] ---
#     - Total Loss: 6.9265
#     - NLL: 1.8268
#     - Reg: 0.2052
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 68]
#   -> Rozdíl (Pred - Target): 1.529781
#   -> Min Variance v batchi:  3.71e-05
#   -> Mean Variance v batchi: 1.68e+01
# --- Iteration [69/800] ---
#     - Total Loss: 10.9351
#     - NLL: 2.3033
#     - Reg: 0.2052
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 69]
#   -> Rozdíl (Pred - Target): 1.395314
#   -> Min Variance v batchi:  5.10e-05
#   -> Mean Variance v batchi: 1.60e+01
# --- Iteration [70/800] ---
#     - Total Loss: 8.6216
#     - NLL: 2.0370
#     - Reg: 0.2052
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 70 ---
#   Average MSE: 18.5315, Average ANEES: 580.8911
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 70]
#   -> Rozdíl (Pred - Target): 1.298164
#   -> Min Variance v batchi:  4.09e-05
#   -> Mean Variance v batchi: 1.55e+01
# --- Iteration [71/800] ---
#     - Total Loss: 6.5077
#     - NLL: 1.8553
#     - Reg: 0.2052
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 71]
#   -> Rozdíl (Pred - Target): 1.337983
#   -> Min Variance v batchi:  3.25e-05
#   -> Mean Variance v batchi: 1.70e+01
# --- Iteration [72/800] ---
#     - Total Loss: 6.8321
#     - NLL: 1.8558
#     - Reg: 0.2051
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 72]
#   -> Rozdíl (Pred - Target): 1.307894
#   -> Min Variance v batchi:  3.75e-05
#   -> Mean Variance v batchi: 1.67e+01
# --- Iteration [73/800] ---
#     - Total Loss: 6.4704
#     - NLL: 1.7404
#     - Reg: 0.2051
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 73]
#   -> Rozdíl (Pred - Target): 1.289875
#   -> Min Variance v batchi:  6.80e-05
#   -> Mean Variance v batchi: 1.56e+01
# --- Iteration [74/800] ---
#     - Total Loss: 6.8904
#     - NLL: 1.8883
#     - Reg: 0.2051
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 74]
#   -> Rozdíl (Pred - Target): 1.411117
#   -> Min Variance v batchi:  3.34e-05
#   -> Mean Variance v batchi: 1.55e+01
# --- Iteration [75/800] ---
#     - Total Loss: 10.8227
#     - NLL: 1.8863
#     - Reg: 0.2051
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 75 ---
#   Average MSE: 19.2023, Average ANEES: 628.7165
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 75]
#   -> Rozdíl (Pred - Target): 1.315247
#   -> Min Variance v batchi:  3.96e-05
#   -> Mean Variance v batchi: 1.52e+01
# --- Iteration [76/800] ---
#     - Total Loss: 6.8730
#     - NLL: 1.7060
#     - Reg: 0.2051
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 76]
#   -> Rozdíl (Pred - Target): 1.273168
#   -> Min Variance v batchi:  4.99e-05
#   -> Mean Variance v batchi: 1.53e+01
# --- Iteration [77/800] ---
#     - Total Loss: 7.1916
#     - NLL: 1.8183
#     - Reg: 0.2051
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 77]
#   -> Rozdíl (Pred - Target): 1.251134
#   -> Min Variance v batchi:  2.53e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [78/800] ---
#     - Total Loss: 6.2079
#     - NLL: 1.8853
#     - Reg: 0.2050
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 78]
#   -> Rozdíl (Pred - Target): 1.272351
#   -> Min Variance v batchi:  3.16e-05
#   -> Mean Variance v batchi: 1.37e+01
# --- Iteration [79/800] ---
#     - Total Loss: 6.8810
#     - NLL: 1.8259
#     - Reg: 0.2050
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 79]
#   -> Rozdíl (Pred - Target): 1.282890
#   -> Min Variance v batchi:  4.67e-05
#   -> Mean Variance v batchi: 1.47e+01
# --- Iteration [80/800] ---
#     - Total Loss: 6.6824
#     - NLL: 1.8489
#     - Reg: 0.2050
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 80 ---
#   Average MSE: 17.3049, Average ANEES: 685.6257
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 80]
#   -> Rozdíl (Pred - Target): 1.248660
#   -> Min Variance v batchi:  3.00e-05
#   -> Mean Variance v batchi: 1.47e+01
# --- Iteration [81/800] ---
#     - Total Loss: 6.5529
#     - NLL: 1.9567
#     - Reg: 0.2050
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 81]
#   -> Rozdíl (Pred - Target): 1.333365
#   -> Min Variance v batchi:  5.48e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [82/800] ---
#     - Total Loss: 7.0357
#     - NLL: 1.8891
#     - Reg: 0.2050
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 82]
#   -> Rozdíl (Pred - Target): 1.365528
#   -> Min Variance v batchi:  5.07e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [83/800] ---
#     - Total Loss: 8.7869
#     - NLL: 1.9747
#     - Reg: 0.2049
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 83]
#   -> Rozdíl (Pred - Target): 1.270966
#   -> Min Variance v batchi:  3.69e-05
#   -> Mean Variance v batchi: 1.53e+01
# --- Iteration [84/800] ---
#     - Total Loss: 6.3421
#     - NLL: 1.8731
#     - Reg: 0.2049
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 84]
#   -> Rozdíl (Pred - Target): 1.251479
#   -> Min Variance v batchi:  4.73e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [85/800] ---
#     - Total Loss: 5.8816
#     - NLL: 1.8541
#     - Reg: 0.2049
#     - p1=0.382, p2=0.301
#
# --- Validation at iteration 85 ---
#   Average MSE: 15.7274, Average ANEES: 669.5331
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 85]
#   -> Rozdíl (Pred - Target): 1.267229
#   -> Min Variance v batchi:  6.22e-05
#   -> Mean Variance v batchi: 1.48e+01
# --- Iteration [86/800] ---
#     - Total Loss: 6.0241
#     - NLL: 1.8349
#     - Reg: 0.2049
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 86]
#   -> Rozdíl (Pred - Target): 1.216250
#   -> Min Variance v batchi:  4.30e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [87/800] ---
#     - Total Loss: 4.7971
#     - NLL: 1.6823
#     - Reg: 0.2049
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 87]
#   -> Rozdíl (Pred - Target): 1.243413
#   -> Min Variance v batchi:  5.66e-05
#   -> Mean Variance v batchi: 1.52e+01
# --- Iteration [88/800] ---
#     - Total Loss: 6.3373
#     - NLL: 1.7724
#     - Reg: 0.2048
#     - p1=0.382, p2=0.301
#
# [DIAGNOSTIKA iter 88]
#   -> Rozdíl (Pred - Target): 1.357308
#   -> Min Variance v batchi:  3.50e-05
#   -> Mean Variance v batchi: 1.76e+01
# --- Iteration [89/800] ---
#     - Total Loss: 7.5961
#     - NLL: 2.1845
#     - Reg: 0.2048
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 89]
#   -> Rozdíl (Pred - Target): 1.323923
#   -> Min Variance v batchi:  4.96e-05
#   -> Mean Variance v batchi: 1.73e+01
# --- Iteration [90/800] ---
#     - Total Loss: 7.4670
#     - NLL: 2.2258
#     - Reg: 0.2048
#     - p1=0.381, p2=0.301
#
# --- Validation at iteration 90 ---
#   Average MSE: 18.6432, Average ANEES: 642.9827
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 90]
#   -> Rozdíl (Pred - Target): 1.271909
#   -> Min Variance v batchi:  3.66e-05
#   -> Mean Variance v batchi: 1.66e+01
# --- Iteration [91/800] ---
#     - Total Loss: 6.5390
#     - NLL: 1.9865
#     - Reg: 0.2048
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 91]
#   -> Rozdíl (Pred - Target): 1.305263
#   -> Min Variance v batchi:  5.02e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [92/800] ---
#     - Total Loss: 7.1701
#     - NLL: 1.9781
#     - Reg: 0.2048
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 92]
#   -> Rozdíl (Pred - Target): 1.246524
#   -> Min Variance v batchi:  4.67e-05
#   -> Mean Variance v batchi: 1.57e+01
# --- Iteration [93/800] ---
#     - Total Loss: 5.6129
#     - NLL: 1.8148
#     - Reg: 0.2047
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 93]
#   -> Rozdíl (Pred - Target): 1.286125
#   -> Min Variance v batchi:  5.43e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [94/800] ---
#     - Total Loss: 6.7807
#     - NLL: 1.9005
#     - Reg: 0.2047
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 94]
#   -> Rozdíl (Pred - Target): 1.270917
#   -> Min Variance v batchi:  4.73e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [95/800] ---
#     - Total Loss: 6.1957
#     - NLL: 1.7433
#     - Reg: 0.2047
#     - p1=0.381, p2=0.301
#
# --- Validation at iteration 95 ---
#   Average MSE: 18.3050, Average ANEES: 641.5670
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 95]
#   -> Rozdíl (Pred - Target): 1.244890
#   -> Min Variance v batchi:  6.07e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [96/800] ---
#     - Total Loss: 5.7235
#     - NLL: 1.6223
#     - Reg: 0.2047
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 96]
#   -> Rozdíl (Pred - Target): 1.245784
#   -> Min Variance v batchi:  4.75e-05
#   -> Mean Variance v batchi: 1.69e+01
# --- Iteration [97/800] ---
#     - Total Loss: 6.1745
#     - NLL: 1.9498
#     - Reg: 0.2047
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 97]
#   -> Rozdíl (Pred - Target): 1.388163
#   -> Min Variance v batchi:  2.69e-05
#   -> Mean Variance v batchi: 1.67e+01
# --- Iteration [98/800] ---
#     - Total Loss: 8.3665
#     - NLL: 1.9778
#     - Reg: 0.2047
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 98]
#   -> Rozdíl (Pred - Target): 1.345531
#   -> Min Variance v batchi:  4.17e-05
#   -> Mean Variance v batchi: 1.57e+01
# --- Iteration [99/800] ---
#     - Total Loss: 8.4958
#     - NLL: 1.9723
#     - Reg: 0.2046
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 99]
#   -> Rozdíl (Pred - Target): 1.282405
#   -> Min Variance v batchi:  4.39e-05
#   -> Mean Variance v batchi: 1.53e+01
# --- Iteration [100/800] ---
#     - Total Loss: 6.6053
#     - NLL: 1.9186
#     - Reg: 0.2046
#     - p1=0.381, p2=0.301
#
# --- Validation at iteration 100 ---
#   Average MSE: 19.5930, Average ANEES: 567.9810
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 100]
#   -> Rozdíl (Pred - Target): 1.276839
#   -> Min Variance v batchi:  5.57e-05
#   -> Mean Variance v batchi: 1.54e+01
# --- Iteration [101/800] ---
#     - Total Loss: 6.6030
#     - NLL: 1.9999
#     - Reg: 0.2046
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 101]
#   -> Rozdíl (Pred - Target): 1.348307
#   -> Min Variance v batchi:  4.29e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [102/800] ---
#     - Total Loss: 8.7856
#     - NLL: 2.1643
#     - Reg: 0.2046
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 102]
#   -> Rozdíl (Pred - Target): 1.286445
#   -> Min Variance v batchi:  5.20e-05
#   -> Mean Variance v batchi: 1.53e+01
# --- Iteration [103/800] ---
#     - Total Loss: 6.2881
#     - NLL: 1.8994
#     - Reg: 0.2046
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 103]
#   -> Rozdíl (Pred - Target): 1.131825
#   -> Min Variance v batchi:  5.83e-05
#   -> Mean Variance v batchi: 1.35e+01
# --- Iteration [104/800] ---
#     - Total Loss: 4.3230
#     - NLL: 1.5234
#     - Reg: 0.2046
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 104]
#   -> Rozdíl (Pred - Target): 1.411076
#   -> Min Variance v batchi:  3.09e-05
#   -> Mean Variance v batchi: 1.56e+01
# --- Iteration [105/800] ---
#     - Total Loss: 9.0129
#     - NLL: 2.2866
#     - Reg: 0.2045
#     - p1=0.381, p2=0.301
#
# --- Validation at iteration 105 ---
#   Average MSE: 18.0029, Average ANEES: 500.2061
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 105]
#   -> Rozdíl (Pred - Target): 1.249495
#   -> Min Variance v batchi:  5.27e-05
#   -> Mean Variance v batchi: 1.34e+01
# --- Iteration [106/800] ---
#     - Total Loss: 6.0651
#     - NLL: 1.7022
#     - Reg: 0.2045
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 106]
#   -> Rozdíl (Pred - Target): 1.278803
#   -> Min Variance v batchi:  2.24e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [107/800] ---
#     - Total Loss: 6.5826
#     - NLL: 1.8557
#     - Reg: 0.2045
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 107]
#   -> Rozdíl (Pred - Target): 1.322727
#   -> Min Variance v batchi:  3.61e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [108/800] ---
#     - Total Loss: 7.4194
#     - NLL: 1.8742
#     - Reg: 0.2045
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 108]
#   -> Rozdíl (Pred - Target): 1.251285
#   -> Min Variance v batchi:  5.21e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [109/800] ---
#     - Total Loss: 6.4148
#     - NLL: 1.6581
#     - Reg: 0.2045
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 109]
#   -> Rozdíl (Pred - Target): 1.244978
#   -> Min Variance v batchi:  2.80e-05
#   -> Mean Variance v batchi: 1.39e+01
# --- Iteration [110/800] ---
#     - Total Loss: 6.3190
#     - NLL: 1.6588
#     - Reg: 0.2045
#     - p1=0.381, p2=0.301
#
# --- Validation at iteration 110 ---
#   Average MSE: 17.2960, Average ANEES: 458.5184
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 110]
#   -> Rozdíl (Pred - Target): 1.298055
#   -> Min Variance v batchi:  3.70e-05
#   -> Mean Variance v batchi: 1.56e+01
# --- Iteration [111/800] ---
#     - Total Loss: 7.2039
#     - NLL: 1.8160
#     - Reg: 0.2044
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 111]
#   -> Rozdíl (Pred - Target): 1.282165
#   -> Min Variance v batchi:  2.29e-05
#   -> Mean Variance v batchi: 1.53e+01
# --- Iteration [112/800] ---
#     - Total Loss: 7.0898
#     - NLL: 1.9801
#     - Reg: 0.2044
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 112]
#   -> Rozdíl (Pred - Target): 1.220653
#   -> Min Variance v batchi:  3.88e-05
#   -> Mean Variance v batchi: 1.54e+01
# --- Iteration [113/800] ---
#     - Total Loss: 6.1991
#     - NLL: 1.5666
#     - Reg: 0.2044
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 113]
#   -> Rozdíl (Pred - Target): 1.293301
#   -> Min Variance v batchi:  5.35e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [114/800] ---
#     - Total Loss: 6.9484
#     - NLL: 1.8444
#     - Reg: 0.2044
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 114]
#   -> Rozdíl (Pred - Target): 1.286880
#   -> Min Variance v batchi:  3.01e-05
#   -> Mean Variance v batchi: 1.58e+01
# --- Iteration [115/800] ---
#     - Total Loss: 7.6429
#     - NLL: 1.9070
#     - Reg: 0.2044
#     - p1=0.381, p2=0.301
#
# --- Validation at iteration 115 ---
#   Average MSE: 17.6490, Average ANEES: 427.7918
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 115]
#   -> Rozdíl (Pred - Target): 1.278802
#   -> Min Variance v batchi:  2.74e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [116/800] ---
#     - Total Loss: 5.9766
#     - NLL: 1.4681
#     - Reg: 0.2043
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 116]
#   -> Rozdíl (Pred - Target): 1.216154
#   -> Min Variance v batchi:  2.78e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [117/800] ---
#     - Total Loss: 5.6299
#     - NLL: 1.6577
#     - Reg: 0.2043
#     - p1=0.381, p2=0.301
#
# [DIAGNOSTIKA iter 117]
#   -> Rozdíl (Pred - Target): 1.228889
#   -> Min Variance v batchi:  4.63e-05
#   -> Mean Variance v batchi: 1.48e+01
# --- Iteration [118/800] ---
#     - Total Loss: 6.2632
#     - NLL: 1.7536
#     - Reg: 0.2043
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 118]
#   -> Rozdíl (Pred - Target): 1.216853
#   -> Min Variance v batchi:  3.97e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [119/800] ---
#     - Total Loss: 5.7454
#     - NLL: 1.7685
#     - Reg: 0.2043
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 119]
#   -> Rozdíl (Pred - Target): 1.357087
#   -> Min Variance v batchi:  3.67e-05
#   -> Mean Variance v batchi: 1.55e+01
# --- Iteration [120/800] ---
#     - Total Loss: 7.7758
#     - NLL: 1.9348
#     - Reg: 0.2043
#     - p1=0.381, p2=0.300
#
# --- Validation at iteration 120 ---
#   Average MSE: 17.3745, Average ANEES: 465.5761
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 120]
#   -> Rozdíl (Pred - Target): 1.184442
#   -> Min Variance v batchi:  3.90e-05
#   -> Mean Variance v batchi: 1.40e+01
# --- Iteration [121/800] ---
#     - Total Loss: 5.4643
#     - NLL: 1.6556
#     - Reg: 0.2043
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 121]
#   -> Rozdíl (Pred - Target): 1.247315
#   -> Min Variance v batchi:  4.15e-05
#   -> Mean Variance v batchi: 1.43e+01
# --- Iteration [122/800] ---
#     - Total Loss: 6.4564
#     - NLL: 1.7146
#     - Reg: 0.2042
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 122]
#   -> Rozdíl (Pred - Target): 1.244433
#   -> Min Variance v batchi:  4.35e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [123/800] ---
#     - Total Loss: 5.8190
#     - NLL: 1.8516
#     - Reg: 0.2042
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 123]
#   -> Rozdíl (Pred - Target): 1.305143
#   -> Min Variance v batchi:  4.88e-05
#   -> Mean Variance v batchi: 1.59e+01
# --- Iteration [124/800] ---
#     - Total Loss: 6.7141
#     - NLL: 2.1784
#     - Reg: 0.2042
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 124]
#   -> Rozdíl (Pred - Target): 1.234982
#   -> Min Variance v batchi:  3.05e-05
#   -> Mean Variance v batchi: 1.40e+01
# --- Iteration [125/800] ---
#     - Total Loss: 5.7354
#     - NLL: 1.7065
#     - Reg: 0.2042
#     - p1=0.381, p2=0.300
#
# --- Validation at iteration 125 ---
#   Average MSE: 18.5221, Average ANEES: 484.1281
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 125]
#   -> Rozdíl (Pred - Target): 1.241190
#   -> Min Variance v batchi:  2.74e-05
#   -> Mean Variance v batchi: 1.35e+01
# --- Iteration [126/800] ---
#     - Total Loss: 5.7158
#     - NLL: 1.5773
#     - Reg: 0.2042
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 126]
#   -> Rozdíl (Pred - Target): 1.185785
#   -> Min Variance v batchi:  3.92e-05
#   -> Mean Variance v batchi: 1.28e+01
# --- Iteration [127/800] ---
#     - Total Loss: 5.1570
#     - NLL: 1.7645
#     - Reg: 0.2042
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 127]
#   -> Rozdíl (Pred - Target): 1.384296
#   -> Min Variance v batchi:  2.92e-05
#   -> Mean Variance v batchi: 1.40e+01
# --- Iteration [128/800] ---
#     - Total Loss: 9.4337
#     - NLL: 1.8623
#     - Reg: 0.2041
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 128]
#   -> Rozdíl (Pred - Target): 1.188220
#   -> Min Variance v batchi:  2.03e-05
#   -> Mean Variance v batchi: 1.26e+01
# --- Iteration [129/800] ---
#     - Total Loss: 5.1786
#     - NLL: 1.5754
#     - Reg: 0.2041
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 129]
#   -> Rozdíl (Pred - Target): 1.218102
#   -> Min Variance v batchi:  3.86e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [130/800] ---
#     - Total Loss: 5.8401
#     - NLL: 1.7090
#     - Reg: 0.2041
#     - p1=0.381, p2=0.300
#
# --- Validation at iteration 130 ---
#   Average MSE: 18.7569, Average ANEES: 470.9563
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 130]
#   -> Rozdíl (Pred - Target): 1.320641
#   -> Min Variance v batchi:  4.60e-05
#   -> Mean Variance v batchi: 1.48e+01
# --- Iteration [131/800] ---
#     - Total Loss: 7.9922
#     - NLL: 2.0330
#     - Reg: 0.2041
#     - p1=0.381, p2=0.300
#
# [DIAGNOSTIKA iter 131]
#   -> Rozdíl (Pred - Target): 1.122993
#   -> Min Variance v batchi:  3.68e-05
#   -> Mean Variance v batchi: 1.29e+01
# --- Iteration [132/800] ---
#     - Total Loss: 4.1789
#     - NLL: 1.4500
#     - Reg: 0.2041
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 132]
#   -> Rozdíl (Pred - Target): 1.300309
#   -> Min Variance v batchi:  2.79e-05
#   -> Mean Variance v batchi: 1.48e+01
# --- Iteration [133/800] ---
#     - Total Loss: 6.8012
#     - NLL: 1.8298
#     - Reg: 0.2040
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 133]
#   -> Rozdíl (Pred - Target): 1.236636
#   -> Min Variance v batchi:  2.24e-05
#   -> Mean Variance v batchi: 1.45e+01
# --- Iteration [134/800] ---
#     - Total Loss: 6.4211
#     - NLL: 1.8402
#     - Reg: 0.2040
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 134]
#   -> Rozdíl (Pred - Target): 1.296712
#   -> Min Variance v batchi:  5.56e-05
#   -> Mean Variance v batchi: 1.45e+01
# --- Iteration [135/800] ---
#     - Total Loss: 7.2655
#     - NLL: 1.6972
#     - Reg: 0.2040
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 135 ---
#   Average MSE: 15.6966, Average ANEES: 377.8695
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 135]
#   -> Rozdíl (Pred - Target): 1.287001
#   -> Min Variance v batchi:  3.24e-05
#   -> Mean Variance v batchi: 1.36e+01
# --- Iteration [136/800] ---
#     - Total Loss: 8.2508
#     - NLL: 1.5939
#     - Reg: 0.2040
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 136]
#   -> Rozdíl (Pred - Target): 1.337177
#   -> Min Variance v batchi:  2.74e-05
#   -> Mean Variance v batchi: 1.68e+01
# --- Iteration [137/800] ---
#     - Total Loss: 7.4297
#     - NLL: 1.7904
#     - Reg: 0.2040
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 137]
#   -> Rozdíl (Pred - Target): 1.287426
#   -> Min Variance v batchi:  4.48e-05
#   -> Mean Variance v batchi: 1.63e+01
# --- Iteration [138/800] ---
#     - Total Loss: 7.2671
#     - NLL: 1.8190
#     - Reg: 0.2040
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 138]
#   -> Rozdíl (Pred - Target): 1.237758
#   -> Min Variance v batchi:  4.30e-05
#   -> Mean Variance v batchi: 1.65e+01
# --- Iteration [139/800] ---
#     - Total Loss: 5.9364
#     - NLL: 1.7994
#     - Reg: 0.2039
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 139]
#   -> Rozdíl (Pred - Target): 1.284056
#   -> Min Variance v batchi:  4.94e-05
#   -> Mean Variance v batchi: 1.60e+01
# --- Iteration [140/800] ---
#     - Total Loss: 6.9796
#     - NLL: 1.5890
#     - Reg: 0.2039
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 140 ---
#   Average MSE: 17.7446, Average ANEES: 408.5703
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 140]
#   -> Rozdíl (Pred - Target): 1.301072
#   -> Min Variance v batchi:  4.93e-05
#   -> Mean Variance v batchi: 1.60e+01
# --- Iteration [141/800] ---
#     - Total Loss: 7.4598
#     - NLL: 1.8956
#     - Reg: 0.2039
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 141]
#   -> Rozdíl (Pred - Target): 1.211501
#   -> Min Variance v batchi:  6.72e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [142/800] ---
#     - Total Loss: 5.6593
#     - NLL: 1.4658
#     - Reg: 0.2039
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 142]
#   -> Rozdíl (Pred - Target): 1.245861
#   -> Min Variance v batchi:  5.75e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [143/800] ---
#     - Total Loss: 5.5178
#     - NLL: 1.6835
#     - Reg: 0.2039
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 143]
#   -> Rozdíl (Pred - Target): 1.343314
#   -> Min Variance v batchi:  1.78e-05
#   -> Mean Variance v batchi: 1.58e+01
# --- Iteration [144/800] ---
#     - Total Loss: 8.3744
#     - NLL: 1.8013
#     - Reg: 0.2039
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 144]
#   -> Rozdíl (Pred - Target): 1.259398
#   -> Min Variance v batchi:  4.82e-05
#   -> Mean Variance v batchi: 1.38e+01
# --- Iteration [145/800] ---
#     - Total Loss: 6.5006
#     - NLL: 1.5865
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 145 ---
#   Average MSE: 20.5601, Average ANEES: 416.2138
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 145]
#   -> Rozdíl (Pred - Target): 1.265545
#   -> Min Variance v batchi:  5.65e-05
#   -> Mean Variance v batchi: 1.48e+01
# --- Iteration [146/800] ---
#     - Total Loss: 6.4876
#     - NLL: 1.6355
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 146]
#   -> Rozdíl (Pred - Target): 1.284066
#   -> Min Variance v batchi:  3.38e-05
#   -> Mean Variance v batchi: 1.47e+01
# --- Iteration [147/800] ---
#     - Total Loss: 6.8684
#     - NLL: 1.8093
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 147]
#   -> Rozdíl (Pred - Target): 1.248759
#   -> Min Variance v batchi:  5.90e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [148/800] ---
#     - Total Loss: 6.5923
#     - NLL: 1.6601
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 148]
#   -> Rozdíl (Pred - Target): 1.220543
#   -> Min Variance v batchi:  4.60e-05
#   -> Mean Variance v batchi: 1.56e+01
# --- Iteration [149/800] ---
#     - Total Loss: 5.8956
#     - NLL: 1.6629
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 149]
#   -> Rozdíl (Pred - Target): 1.222390
#   -> Min Variance v batchi:  2.40e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [150/800] ---
#     - Total Loss: 6.0477
#     - NLL: 1.5970
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 150 ---
#   Average MSE: 20.1575, Average ANEES: 389.4771
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 150]
#   -> Rozdíl (Pred - Target): 1.259692
#   -> Min Variance v batchi:  4.14e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [151/800] ---
#     - Total Loss: 6.2555
#     - NLL: 1.6949
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 151]
#   -> Rozdíl (Pred - Target): 1.199628
#   -> Min Variance v batchi:  4.38e-05
#   -> Mean Variance v batchi: 1.46e+01
# --- Iteration [152/800] ---
#     - Total Loss: 5.5390
#     - NLL: 1.3537
#     - Reg: 0.2038
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 152]
#   -> Rozdíl (Pred - Target): 1.217548
#   -> Min Variance v batchi:  3.94e-05
#   -> Mean Variance v batchi: 1.62e+01
# --- Iteration [153/800] ---
#     - Total Loss: 5.6198
#     - NLL: 1.7948
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 153]
#   -> Rozdíl (Pred - Target): 1.269379
#   -> Min Variance v batchi:  2.64e-05
#   -> Mean Variance v batchi: 1.51e+01
# --- Iteration [154/800] ---
#     - Total Loss: 6.6115
#     - NLL: 1.6526
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 154]
#   -> Rozdíl (Pred - Target): 1.257340
#   -> Min Variance v batchi:  3.72e-05
#   -> Mean Variance v batchi: 1.57e+01
# --- Iteration [155/800] ---
#     - Total Loss: 6.3080
#     - NLL: 1.6826
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 155 ---
#   Average MSE: 16.7562, Average ANEES: 373.3804
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 155]
#   -> Rozdíl (Pred - Target): 1.246951
#   -> Min Variance v batchi:  3.88e-05
#   -> Mean Variance v batchi: 1.61e+01
# --- Iteration [156/800] ---
#     - Total Loss: 6.0968
#     - NLL: 1.6480
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 156]
#   -> Rozdíl (Pred - Target): 1.221846
#   -> Min Variance v batchi:  4.10e-05
#   -> Mean Variance v batchi: 1.49e+01
# --- Iteration [157/800] ---
#     - Total Loss: 5.6048
#     - NLL: 1.7458
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 157]
#   -> Rozdíl (Pred - Target): 1.248648
#   -> Min Variance v batchi:  3.58e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [158/800] ---
#     - Total Loss: 6.2664
#     - NLL: 1.7216
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 158]
#   -> Rozdíl (Pred - Target): 1.251382
#   -> Min Variance v batchi:  4.94e-05
#   -> Mean Variance v batchi: 1.56e+01
# --- Iteration [159/800] ---
#     - Total Loss: 6.5730
#     - NLL: 1.8494
#     - Reg: 0.2037
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 159]
#   -> Rozdíl (Pred - Target): 1.301893
#   -> Min Variance v batchi:  2.97e-05
#   -> Mean Variance v batchi: 1.74e+01
# --- Iteration [160/800] ---
#     - Total Loss: 7.3445
#     - NLL: 1.8363
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 160 ---
#   Average MSE: 19.1301, Average ANEES: 347.6181
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 160]
#   -> Rozdíl (Pred - Target): 1.283639
#   -> Min Variance v batchi:  4.10e-05
#   -> Mean Variance v batchi: 1.47e+01
# --- Iteration [161/800] ---
#     - Total Loss: 7.0969
#     - NLL: 1.7917
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 161]
#   -> Rozdíl (Pred - Target): 1.244162
#   -> Min Variance v batchi:  3.89e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [162/800] ---
#     - Total Loss: 5.8628
#     - NLL: 1.5382
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 162]
#   -> Rozdíl (Pred - Target): 1.349187
#   -> Min Variance v batchi:  3.75e-05
#   -> Mean Variance v batchi: 1.65e+01
# --- Iteration [163/800] ---
#     - Total Loss: 8.0590
#     - NLL: 2.0561
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 163]
#   -> Rozdíl (Pred - Target): 1.296714
#   -> Min Variance v batchi:  3.71e-05
#   -> Mean Variance v batchi: 1.43e+01
# --- Iteration [164/800] ---
#     - Total Loss: 7.2991
#     - NLL: 1.7053
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 164]
#   -> Rozdíl (Pred - Target): 1.209380
#   -> Min Variance v batchi:  3.49e-05
#   -> Mean Variance v batchi: 1.40e+01
# --- Iteration [165/800] ---
#     - Total Loss: 5.7279
#     - NLL: 1.5379
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# --- Validation at iteration 165 ---
#   Average MSE: 20.8078, Average ANEES: 353.1147
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 165]
#   -> Rozdíl (Pred - Target): 1.145231
#   -> Min Variance v batchi:  6.27e-05
#   -> Mean Variance v batchi: 1.34e+01
# --- Iteration [166/800] ---
#     - Total Loss: 4.7259
#     - NLL: 1.3606
#     - Reg: 0.2036
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 166]
#   -> Rozdíl (Pred - Target): 1.374146
#   -> Min Variance v batchi:  3.73e-05
#   -> Mean Variance v batchi: 1.50e+01
# --- Iteration [167/800] ---
#     - Total Loss: 9.6905
#     - NLL: 1.8798
#     - Reg: 0.2035
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 167]
#   -> Rozdíl (Pred - Target): 1.245807
#   -> Min Variance v batchi:  5.12e-05
#   -> Mean Variance v batchi: 1.41e+01
# --- Iteration [168/800] ---
#     - Total Loss: 6.9737
#     - NLL: 1.5517
#     - Reg: 0.2035
#     - p1=0.380, p2=0.300
#
# [DIAGNOSTIKA iter 168]
#   -> Rozdíl (Pred - Target): 1.266653
# ...
# --- Iteration [568/800] ---
#     - Total Loss: 0.7986
#     - NLL: 0.6246
#     - Reg: 0.1740
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 568]
#   -> Rozdíl (Pred - Target): 1.274607
#   -> Min Variance v batchi:  5.22e-05
#   -> Mean Variance v batchi: 1.00e+01
# --- Iteration [569/800] ---
#     - Total Loss: 1.2842
#     - NLL: 1.1102
#     - Reg: 0.1740
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 569]
#   -> Rozdíl (Pred - Target): 1.064297
#   -> Min Variance v batchi:  4.71e-05
#   -> Mean Variance v batchi: 8.18e+00
# --- Iteration [570/800] ---
#     - Total Loss: 0.9389
#     - NLL: 0.7651
#     - Reg: 0.1739
#     - p1=0.365, p2=0.289
#
# --- Validation at iteration 570 ---
#   Average MSE: 17.7864, Average ANEES: 82.0306
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 570]
#   -> Rozdíl (Pred - Target): 1.345739
#   -> Min Variance v batchi:  3.91e-05
#   -> Mean Variance v batchi: 1.20e+01
# --- Iteration [571/800] ---
#     - Total Loss: 1.3390
#     - NLL: 1.1652
#     - Reg: 0.1738
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 571]
#   -> Rozdíl (Pred - Target): 1.169328
#   -> Min Variance v batchi:  4.69e-05
#   -> Mean Variance v batchi: 8.76e+00
# --- Iteration [572/800] ---
#     - Total Loss: 0.9640
#     - NLL: 0.7902
#     - Reg: 0.1738
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 572]
#   -> Rozdíl (Pred - Target): 1.164083
#   -> Min Variance v batchi:  4.01e-05
#   -> Mean Variance v batchi: 8.81e+00
# --- Iteration [573/800] ---
#     - Total Loss: 0.9504
#     - NLL: 0.7767
#     - Reg: 0.1737
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 573]
#   -> Rozdíl (Pred - Target): 1.330308
#   -> Min Variance v batchi:  3.95e-05
#   -> Mean Variance v batchi: 1.03e+01
# --- Iteration [574/800] ---
#     - Total Loss: 1.3795
#     - NLL: 1.2059
#     - Reg: 0.1736
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 574]
#   -> Rozdíl (Pred - Target): 1.195441
#   -> Min Variance v batchi:  3.73e-05
#   -> Mean Variance v batchi: 9.28e+00
# --- Iteration [575/800] ---
#     - Total Loss: 1.0629
#     - NLL: 0.8894
#     - Reg: 0.1736
#     - p1=0.365, p2=0.289
#
# --- Validation at iteration 575 ---
#   Average MSE: 15.6479, Average ANEES: 81.5409
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 575]
#   -> Rozdíl (Pred - Target): 1.211599
#   -> Min Variance v batchi:  5.08e-05
#   -> Mean Variance v batchi: 8.32e+00
# --- Iteration [576/800] ---
#     - Total Loss: 0.9759
#     - NLL: 0.8023
#     - Reg: 0.1735
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 576]
#   -> Rozdíl (Pred - Target): 1.218933
#   -> Min Variance v batchi:  4.30e-05
#   -> Mean Variance v batchi: 1.01e+01
# --- Iteration [577/800] ---
#     - Total Loss: 1.2209
#     - NLL: 1.0474
#     - Reg: 0.1735
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 577]
#   -> Rozdíl (Pred - Target): 1.181899
#   -> Min Variance v batchi:  3.95e-05
#   -> Mean Variance v batchi: 9.24e+00
# --- Iteration [578/800] ---
#     - Total Loss: 1.0904
#     - NLL: 0.9170
#     - Reg: 0.1734
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 578]
#   -> Rozdíl (Pred - Target): 1.159463
#   -> Min Variance v batchi:  6.52e-05
#   -> Mean Variance v batchi: 8.90e+00
# --- Iteration [579/800] ---
#     - Total Loss: 0.9457
#     - NLL: 0.7724
#     - Reg: 0.1733
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 579]
#   -> Rozdíl (Pred - Target): 1.137065
#   -> Min Variance v batchi:  7.18e-05
#   -> Mean Variance v batchi: 1.02e+01
# --- Iteration [580/800] ---
#     - Total Loss: 0.8915
#     - NLL: 0.7183
#     - Reg: 0.1733
#     - p1=0.365, p2=0.289
#
# --- Validation at iteration 580 ---
#   Average MSE: 15.5295, Average ANEES: 67.1493
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 580]
#   -> Rozdíl (Pred - Target): 1.308091
#   -> Min Variance v batchi:  3.80e-05
#   -> Mean Variance v batchi: 1.11e+01
# --- Iteration [581/800] ---
#     - Total Loss: 1.3144
#     - NLL: 1.1412
#     - Reg: 0.1732
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 581]
#   -> Rozdíl (Pred - Target): 1.103248
#   -> Min Variance v batchi:  2.91e-05
#   -> Mean Variance v batchi: 8.86e+00
# --- Iteration [582/800] ---
#     - Total Loss: 0.8943
#     - NLL: 0.7211
#     - Reg: 0.1732
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 582]
#   -> Rozdíl (Pred - Target): 1.085816
#   -> Min Variance v batchi:  4.56e-05
#   -> Mean Variance v batchi: 7.51e+00
# --- Iteration [583/800] ---
#     - Total Loss: 0.8548
#     - NLL: 0.6817
#     - Reg: 0.1731
#     - p1=0.365, p2=0.289
#
# [DIAGNOSTIKA iter 583]
#   -> Rozdíl (Pred - Target): 1.163851
#   -> Min Variance v batchi:  2.77e-05
#   -> Mean Variance v batchi: 9.56e+00
# --- Iteration [584/800] ---
#     - Total Loss: 1.1485
#     - NLL: 0.9754
#     - Reg: 0.1730
#     - p1=0.364, p2=0.289
#
# [DIAGNOSTIKA iter 584]
#   -> Rozdíl (Pred - Target): 1.250186
#   -> Min Variance v batchi:  5.71e-05
#   -> Mean Variance v batchi: 9.47e+00
# --- Iteration [585/800] ---
#     - Total Loss: 1.0955
#     - NLL: 0.9225
#     - Reg: 0.1730
#     - p1=0.364, p2=0.289
#
# --- Validation at iteration 585 ---
#   Average MSE: 16.6262, Average ANEES: 75.3415
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 585]
#   -> Rozdíl (Pred - Target): 1.164873
#   -> Min Variance v batchi:  3.16e-05
#   -> Mean Variance v batchi: 8.84e+00
# --- Iteration [586/800] ---
#     - Total Loss: 0.9777
#     - NLL: 0.8048
#     - Reg: 0.1729
#     - p1=0.364, p2=0.289
#
# [DIAGNOSTIKA iter 586]
#   -> Rozdíl (Pred - Target): 1.183850
#   -> Min Variance v batchi:  3.28e-05
#   -> Mean Variance v batchi: 8.72e+00
# --- Iteration [587/800] ---
#     - Total Loss: 1.0482
#     - NLL: 0.8753
#     - Reg: 0.1729
#     - p1=0.364, p2=0.289
#
# [DIAGNOSTIKA iter 587]
#   -> Rozdíl (Pred - Target): 1.211483
#   -> Min Variance v batchi:  4.18e-05
#   -> Mean Variance v batchi: 1.01e+01
# --- Iteration [588/800] ---
#     - Total Loss: 1.1392
#     - NLL: 0.9664
#     - Reg: 0.1728
#     - p1=0.364, p2=0.289
#
# [DIAGNOSTIKA iter 588]
#   -> Rozdíl (Pred - Target): 1.222667
#   -> Min Variance v batchi:  4.70e-05
#   -> Mean Variance v batchi: 9.03e+00
# --- Iteration [589/800] ---
#     - Total Loss: 0.9851
#     - NLL: 0.8123
#     - Reg: 0.1727
#     - p1=0.364, p2=0.289
#
# [DIAGNOSTIKA iter 589]
#   -> Rozdíl (Pred - Target): 1.222034
#   -> Min Variance v batchi:  2.32e-05
#   -> Mean Variance v batchi: 9.39e+00
# --- Iteration [590/800] ---
#     - Total Loss: 1.1480
#     - NLL: 0.9753
#     - Reg: 0.1727
#     - p1=0.364, p2=0.289
#
# --- Validation at iteration 590 ---
#   Average MSE: 18.5576, Average ANEES: 69.1423
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 590]
#   -> Rozdíl (Pred - Target): 1.177594
#   -> Min Variance v batchi:  6.56e-05
#   -> Mean Variance v batchi: 8.53e+00
# --- Iteration [591/800] ---
#     - Total Loss: 0.9328
#     - NLL: 0.7602
#     - Reg: 0.1726
#     - p1=0.364, p2=0.289
#
# [DIAGNOSTIKA iter 591]
#   -> Rozdíl (Pred - Target): 1.260110
#   -> Min Variance v batchi:  3.73e-05
#   -> Mean Variance v batchi: 8.75e+00
# --- Iteration [592/800] ---
#     - Total Loss: 1.0608
#     - NLL: 0.8882
#     - Reg: 0.1726
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 592]
#   -> Rozdíl (Pred - Target): 1.171702
#   -> Min Variance v batchi:  4.47e-05
#   -> Mean Variance v batchi: 9.33e+00
# --- Iteration [593/800] ---
#     - Total Loss: 1.0229
#     - NLL: 0.8505
#     - Reg: 0.1725
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 593]
#   -> Rozdíl (Pred - Target): 1.148934
#   -> Min Variance v batchi:  5.25e-05
#   -> Mean Variance v batchi: 1.01e+01
# --- Iteration [594/800] ---
#     - Total Loss: 1.0800
#     - NLL: 0.9075
#     - Reg: 0.1724
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 594]
#   -> Rozdíl (Pred - Target): 1.284510
#   -> Min Variance v batchi:  3.70e-05
#   -> Mean Variance v batchi: 9.93e+00
# --- Iteration [595/800] ---
#     - Total Loss: 1.2891
#     - NLL: 1.1167
#     - Reg: 0.1724
#     - p1=0.364, p2=0.288
#
# --- Validation at iteration 595 ---
#   Average MSE: 15.9774, Average ANEES: 86.7436
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 595]
#   -> Rozdíl (Pred - Target): 1.138184
#   -> Min Variance v batchi:  5.80e-05
#   -> Mean Variance v batchi: 8.21e+00
# --- Iteration [596/800] ---
#     - Total Loss: 0.8736
#     - NLL: 0.7013
#     - Reg: 0.1723
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 596]
#   -> Rozdíl (Pred - Target): 1.139621
#   -> Min Variance v batchi:  4.71e-05
#   -> Mean Variance v batchi: 9.47e+00
# --- Iteration [597/800] ---
#     - Total Loss: 0.9313
#     - NLL: 0.7591
#     - Reg: 0.1722
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 597]
#   -> Rozdíl (Pred - Target): 1.365882
#   -> Min Variance v batchi:  3.11e-05
#   -> Mean Variance v batchi: 1.18e+01
# --- Iteration [598/800] ---
#     - Total Loss: 1.1630
#     - NLL: 0.9908
#     - Reg: 0.1721
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 598]
#   -> Rozdíl (Pred - Target): 1.257458
#   -> Min Variance v batchi:  4.71e-05
#   -> Mean Variance v batchi: 1.09e+01
# --- Iteration [599/800] ---
#     - Total Loss: 1.2316
#     - NLL: 1.0595
#     - Reg: 0.1721
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 599]
#   -> Rozdíl (Pred - Target): 1.187186
#   -> Min Variance v batchi:  4.93e-05
#   -> Mean Variance v batchi: 8.23e+00
# --- Iteration [600/800] ---
#     - Total Loss: 1.0670
#     - NLL: 0.8950
#     - Reg: 0.1720
#     - p1=0.364, p2=0.288
#
# --- Validation at iteration 600 ---
#   Average MSE: 14.9597, Average ANEES: 60.7539
#   >>> New best VALIDATION ANEES! Saving model. <<<
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 600]
#   -> Rozdíl (Pred - Target): 1.189006
#   -> Min Variance v batchi:  4.77e-05
#   -> Mean Variance v batchi: 1.10e+01
# --- Iteration [601/800] ---
#     - Total Loss: 1.0888
#     - NLL: 0.9168
#     - Reg: 0.1720
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 601]
#   -> Rozdíl (Pred - Target): 1.197961
#   -> Min Variance v batchi:  3.48e-05
#   -> Mean Variance v batchi: 9.56e+00
# --- Iteration [602/800] ---
#     - Total Loss: 1.0303
#     - NLL: 0.8584
#     - Reg: 0.1719
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 602]
#   -> Rozdíl (Pred - Target): 1.112897
#   -> Min Variance v batchi:  4.96e-05
#   -> Mean Variance v batchi: 9.54e+00
# --- Iteration [603/800] ---
#     - Total Loss: 0.8511
#     - NLL: 0.6793
#     - Reg: 0.1718
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 603]
#   -> Rozdíl (Pred - Target): 1.167501
#   -> Min Variance v batchi:  4.65e-05
#   -> Mean Variance v batchi: 1.02e+01
# --- Iteration [604/800] ---
#     - Total Loss: 1.1905
#     - NLL: 1.0188
#     - Reg: 0.1718
#     - p1=0.364, p2=0.288
#
# [DIAGNOSTIKA iter 604]
#   -> Rozdíl (Pred - Target): 1.193366
#   -> Min Variance v batchi:  5.28e-05
#   -> Mean Variance v batchi: 9.20e+00
# --- Iteration [605/800] ---
#     - Total Loss: 1.0916
#     - NLL: 0.9199
#     - Reg: 0.1717
#     - p1=0.364, p2=0.288
#
# --- Validation at iteration 605 ---
#   Average MSE: 17.3677, Average ANEES: 77.8809
# --------------------------------------------------
#
# [DIAGNOSTIKA iter 605]
#   -> Rozdíl (Pred - Target): 1.242199
#   -> Min Variance v batchi:  5.26e-05
#   -> Mean Variance v batchi: 1.02e+01
# --- Iteration [606/800] ---
#     - Total Loss: 1.1422
#     - NLL: 0.9706
#     - Reg: 0.1716
#     - p1=0.364, p2=0.288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 48
#      45 validation_period = 5  # Chceme validovat jednou za epochu (na konci)
#      47 # 3. Volání funkce
# ---> 48 trained_knet = trainer.train_BayesianKalmanNetNCLT_test(
#      49     model=state_knet,
#      50     train_loader=train_loader,
#      51     val_loader=val_loader,
#      52     device=DEVICE,
#      53
#      54     # Parametry iterací
#      55     total_train_iter=total_iterations,
#      56     learning_rate=1e-4,       # Opatrný LR pro BKN
#      57     clip_grad=0.5,            # Stabilizace gradientů
#      58     J_samples=10,              # Počet MC vzorků (paralelně)
#      59
#      60     # Logování a validace
#      61     validation_period=validation_period,
#      62     logging_period=1,        # Výpis loss každých 1 batchu
#      63
#      64     # Warmup
#      65     warmup_iterations=warmup_iterations,
#      66     weight_decay_=1e-4,
#      67     optimizer_type=torch.optim.AdamW
#      68 )
#
# File ~/skola/KalmanNet-main/utils/trainer.py:2271, in train_BayesianKalmanNetNCLT_test(model, train_loader, val_loader, device, total_train_iter, learning_rate, clip_grad, J_samples, validation_period, logging_period, warmup_iterations, weight_decay_, optimizer_type)
#    2269 y_t = y_meas_batch[:, t, :]
#    2270 u_t = u_input_batch[:,t,:]
# -> 2271 x_filtered_t, reg_t = model.step(y_t,u_t)
#    2272 if torch.isnan(x_filtered_t).any():
#    2273         raise ValueError(f"NaN in x_filtered_t at sample {j}, step {t}")
#
# File ~/skola/KalmanNet-main/state_NN_models/NCLT/StateBayesianKalmanNetNCLT_Diagnostic.py:158, in StateBayesianKalmanNetNCLT_Diagnostic.step(self, y_t, u_t)
#     155 norm_state_inno = F.normalize(state_inno, p=2, dim=1, eps=1e-12)
#     157 # 4. NETWORK FORWARD
# --> 158 K_vec, h_new, regs = self.dnn(norm_state_inno, norm_innovation, norm_diff_state, norm_diff_obs, self.h_prev)
#     160 K = K_vec.reshape(-1, self.state_dim, self.obs_dim)
#     161 mask_expanded = mask.unsqueeze(2)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/skola/KalmanNet-main/state_NN_models/NCLT/DNN_BayesianKalmanNet_test.py:52, in DNN_BayesianKalmanNetNCLT_test.forward(self, state_inno, inovation, diff_state, diff_obs, h_prev)
#      49 out_gru, h_new = self.gru(activated_input.unsqueeze(0), h_prev)
#      50 out_gru_squeezed = out_gru.squeeze(0)
# ---> 52 out_final, reg2 = self.concrete_dropout2(out_gru_squeezed, self.output_layer)
#      54 total_reg = reg1+reg2
#      55 return out_final, h_new, total_reg
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/skola/KalmanNet-main/state_NN_models/NCLT/DNN_BayesianKalmanNet_test.py:81, in ConcreteDropout.forward(self, x, layer)
#      78 def forward(self, x, layer):
#      79     p = torch.sigmoid(self.p_logit.to(x.device)) # p je mezi 0 a 1
# ---> 81     x_dropped = self._concrete_dropout(x, p)
#      82     out = layer(x_dropped)
#      84     sum_of_squares = 0
#
# File ~/skola/KalmanNet-main/state_NN_models/NCLT/DNN_BayesianKalmanNet_test.py:109, in ConcreteDropout._concrete_dropout(self, x, p)
#     105 t = 0.1
#     107 unif_noise = torch.rand_like(x) # ve clanku je to parametr u - U(0,1)
# --> 109 drop_prob = (torch.log(p+eps) - torch.log(1. - p+eps) + torch.log(unif_noise+eps) - torch.log(1. - unif_noise+eps))
#     110 drop_prob = torch.sigmoid(drop_prob / t) # pravdepodobnost vypnuti neuronu
#     112 random_tensor = 1. - drop_prob
#
# KeyboardInterrupt:

# %%
# import gc
# import torch

# # === GPU/CUDA Cleanup Helper (Models Only) ===
# # Frees GPU memory by moving neural nets to CPU, deleting their references,
# # forcing GC, and clearing CUDA cache. Does NOT remove DataLoaders or trainer.

# def _cuda_mem_info():
#     if torch.cuda.is_available():
#         alloc = torch.cuda.memory_allocated() / 1e6
#         reserv = torch.cuda.memory_reserved() / 1e6
#         print(f"CUDA mem -> Allocated: {alloc:.1f} MB | Reserved: {reserv:.1f} MB")
#     else:
#         print("CUDA not available.")

# print("Before cleanup:")
# _cuda_mem_info()

# # Release neural network models only
# for name in ["state_knet", "trained_model_bkn"]:
#     if name in globals():
#         obj = globals()[name]
#         try:
#             obj.to("cpu")
#         except Exception:
#             pass
#         # Drop common optimizer/scheduler refs if attached to the model
#         for attr in ["optimizer", "opt", "optim", "scheduler"]:
#             if hasattr(obj, attr):
#                 try:
#                     delattr(obj, attr)
#                 except Exception:
#                     pass
#         del globals()[name]
#         print(f"Released model '{name}' and deleted reference")

# # Force Python GC and clear CUDA cache
# gc.collect()
# if torch.cuda.is_available():
#     try:
#         torch.cuda.synchronize()
#     except Exception:
#         pass
#     torch.cuda.empty_cache()
#     try:
#         torch.cuda.ipc_collect()
#     except Exception:
#         pass

# print("After cleanup:")
# _cuda_mem_info()

# %%
if True:
    import torch
    import os

    # Protože jsi trénink přerušil, nemáme slovník s metrikami automaticky.
    # Musíme uložit přímo model 'state_knet'.

    # 1. Definuj cestu (Metriky si do názvu musíš dopsat ručně podle toho, co jsi viděl v logu naposledy,
    # nebo použij obecný název, abys o model nepřišel).
    save_path = 'BKN_aggresive_jitter.pth'
    # Pokud si pamatuješ hodnoty z logu (např. ANEES 23.5), můžeš je tam dopsat ručně:
    # save_path = 'best_kalmannet_nclt_sensor_fusion_ANEES23.57_MSE8.17_interrupted.pth'

    # 2. Uložení
    # DŮLEŽITÉ: Voláme .state_dict() přímo na objektu state_knet (nebo trained_knet, pokud jsi ho přiřadil)
    # Nepoužíváme závorky ['final_model'], protože state_knet UŽ JE ten model.
    torch.save(state_knet.state_dict(), save_path)

    print(f"\n✅ Záchrana modelu úspěšná! Uloženo do: {save_path}")

if False:
    import os
    trained_knet = state_knet 
    # Přístup k metrikám ve slovníku je správně (přes závorky [])
    print(f"   -> Best ANEES: {trained_knet['best_val_anees']:.4f}")
    print(f"   -> Best MSE:   {trained_knet['best_val_mse']:.4f}")
    save_path = f'best_kalmannet_nclt_sensor_fusion_ANEES{trained_knet["best_val_anees"]:.4f}_MSE{trained_knet["best_val_mse"]:.4f}_nejlepsi_test_vysledky.pth '

    # OPRAVA: Musíš vytáhnout model ze slovníku pomocí klíče 'final_model'
    # A teprve na něm zavolat .state_dict()
    torch.save(trained_knet['final_model'].state_dict(), save_path)

    print(f"\n✅ Model úspěšně uložen do: {save_path}")
# Out:
# ✅ Záchrana modelu úspěšná! Uloženo do: BKN_aggresive_jitter.pth

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import Filters

# ==============================================================================
# 0. KONFIGURACE A MODEL
# ==============================================================================
DT_SEC = 1.0 
J_SAMPLES = 50  # 50 vzorků pro kvalitní odhad distribuce

if hasattr(sys_model, 'dt'):
    sys_model.dt = DT_SEC
    print(f"INFO: Nastaveno sys_model.dt = {DT_SEC} s")

# Načtení Bayesian modelu
try:
    trained_model_bkn = state_knet
    trained_model_bkn.eval()
    print(f"INFO: Používám Bayesian KalmanNet s J={J_SAMPLES} vzorky.")
except NameError:
    raise NameError("Chyba: 'state_knet' (BKN) neexistuje.")

from Filters import NCLT
# Inicializace klasických filtrů
ukf_filter = NCLT.UnscentedKalmanFilterNCLT(sys_model) 
ekf_filter = NCLT.ExtendedKalmanFilterNCLT(sys_model)

# --- ROBUSTNÍ FUNKCE PRO ANEES ---
def calculate_anees(x_true, x_est, P_est):
    """
    Vypočítá ANEES. Očekává vstupy už se shodnou dimenzí.
    Používá pinv pro stabilitu.
    """
    T = x_true.shape[0]
    anees_list = []
    error = x_true - x_est 

    for t in range(T):
        e_t = error[t].unsqueeze(1) # [n, 1]
        P_t = P_est[t]              # [n, n]
        
        try:
            P_inv = torch.linalg.pinv(P_t, hermitian=True)
        except RuntimeError:
            P_inv = torch.eye(P_t.shape[0], device=P_t.device)
            
        nees = torch.mm(torch.mm(e_t.t(), P_inv), e_t).item()
        anees_list.append(nees)
        
    return np.mean(anees_list)

# ==============================================================================
# 1. EVALUACE A VIZUALIZACE
# ==============================================================================
results = {
    'GPS_Sensor': [],   'GPS_Authors': [],  
    'EKF_MSE': [],      'EKF_ANEES': [],
    'UKF_MSE': [],      'UKF_ANEES': [],
    'BKN_MSE': [],      'BKN_ANEES': []
}

print(f"\nSpouštím detailní evaluaci na {len(test_data_raw)} trajektoriích...")

# HLAVIČKA DETAILNÍ TABULKY
print("\n" + "-"*95)
print(f"{'TRAJEKTORIE':<12} | {'BKN MSE':<10} | {'BKN ANEES':<10} | {'EKF MSE':<10} | {'EKF ANEES':<10} | {'GPS MSE':<10}")
print("-" * 95)

for i, traj in enumerate(test_data_raw):
    # --- PŘÍPRAVA DAT ---
    gt_raw = traj['ground_truth'].float().to(DEVICE)
    gps_filtered = traj['filtered_gps'].float().to(DEVICE)
    gps_filled = traj['gps'].float().to(DEVICE)
    imu_raw = traj['imu'].float().to(DEVICE)
    odo_raw = traj['filtered_wheel'].float().to(DEVICE)
    
    T_len = gt_raw.shape[0]
    
    # Input vector
    u_full = torch.stack((
        torch.nan_to_num(odo_raw[:, 0], nan=0.0),
        torch.nan_to_num(odo_raw[:, 1], nan=0.0),
        imu_raw[:, 2], 
        imu_raw[:, 3]
    ), dim=1).to(DEVICE)
    
    # Init State (bereme z GT)
    # x_true má dimenzi 3 (X, Y, Theta)
    x_true = gt_raw[:, :3] 
    
    # Init pro filtry (plná dimenze modelu)
    m = sys_model.state_dim
    x0_vec = torch.zeros(m).to(DEVICE)
    x0_vec[0] = x_true[0, 0]; x0_vec[1] = x_true[0, 1]
    if m >= 3 and x_true.shape[1] >= 3: x0_vec[4] = x_true[0, 2] 

    # --- A. BĚH BAYESIAN KALMANNET ---
    trained_model_bkn.train() # Nutné pro MC Dropout
    
    batch_x0 = x0_vec.unsqueeze(0).repeat(J_SAMPLES, 1)
    trained_model_bkn.reset(batch_size=J_SAMPLES, initial_state=batch_x0)
    
    bkn_samples = []
    bkn_samples.append(batch_x0.unsqueeze(1))

    with torch.no_grad():
        for t in range(1, T_len):
            y_t = gps_filtered[t].unsqueeze(0).repeat(J_SAMPLES, 1)
            u_t = u_full[t].unsqueeze(0).repeat(J_SAMPLES, 1)
            x_est_j, _ = trained_model_bkn.step(y_t, u_t)
            bkn_samples.append(x_est_j.unsqueeze(1))

    trained_model_bkn.eval() 
    bkn_ensemble = torch.cat(bkn_samples, dim=1) # [J, T, m]
    
    # Statistiky BKN
    x_bkn_mean = torch.mean(bkn_ensemble, dim=0) 
    
    # Výpočet kovariance BKN
    centered = bkn_ensemble - x_bkn_mean.unsqueeze(0)
    centered_perm = centered.permute(1, 2, 0) 
    P_bkn = torch.bmm(centered_perm, centered_perm.transpose(1, 2)) / (J_SAMPLES - 1)
    P_bkn = P_bkn + torch.eye(m, device=DEVICE).unsqueeze(0) * 1e-6 

    # --- B. EKF & UKF ---
    def run_filter(flt):
        try:
            res = flt.process_sequence(gps_filtered, u_seq=u_full, Ex0=x0_vec, P0=sys_model.P0)
            return res['x_filtered'], res.get('P_filtered', torch.eye(m, device=DEVICE).repeat(T_len, 1, 1))
        except:
            return torch.zeros(T_len, m).to(DEVICE), torch.eye(m, device=DEVICE).repeat(T_len, 1, 1)

    x_ekf, P_ekf = run_filter(ekf_filter)
    x_ukf, P_ukf = run_filter(ukf_filter)

    # --- VYHODNOCENÍ (SLICING) ---
    eval_dim = x_true.shape[1] # 3 (X, Y, Theta)

    def evaluate_metrics(est_x, est_P):
        # MSE (poloha X, Y)
        mse = F.mse_loss(est_x[:, :2], x_true[:, :2]).item()
        # ANEES (Oříznuté na eval_dim)
        est_x_sliced = est_x[:, :eval_dim]
        est_P_sliced = est_P[:, :eval_dim, :eval_dim]
        anees = calculate_anees(x_true, est_x_sliced, est_P_sliced)
        return mse, anees

    mse_ekf, anees_ekf = evaluate_metrics(x_ekf, P_ekf)
    mse_ukf, anees_ukf = evaluate_metrics(x_ukf, P_ukf)
    mse_bkn, anees_bkn = evaluate_metrics(x_bkn_mean, P_bkn)
    
    valid_mask = ~torch.isnan(gps_filtered[:, 0])
    mse_gps = F.mse_loss(gps_filtered[valid_mask], x_true[valid_mask, :2]).item() if valid_mask.sum() > 0 else np.nan

    # Ukládání
    results['GPS_Sensor'].append(mse_gps)
    results['EKF_MSE'].append(mse_ekf); results['EKF_ANEES'].append(anees_ekf)
    results['UKF_MSE'].append(mse_ukf); results['UKF_ANEES'].append(anees_ukf)
    results['BKN_MSE'].append(mse_bkn); results['BKN_ANEES'].append(anees_bkn)

    # --- VÝPIS ŘÁDKU TABULKY ---
    print(f"{i+1:<12} | {mse_bkn:<10.2f} | {anees_bkn:<10.2f} | {mse_ekf:<10.2f} | {anees_ekf:<10.2f} | {mse_gps:<10.2f}")

    # --- VIZUALIZACE ---
    gt_np = x_true.cpu().numpy()
    bkn_np = x_bkn_mean.cpu().numpy()
    std_x_bkn = torch.sqrt(P_bkn[:, 0, 0]).cpu().numpy()
    t_axis = np.arange(T_len)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    
    # Graf 1: 2D Trajektorie
    ax1.plot(gt_np[:, 0], gt_np[:, 1], 'k-', lw=2, label='Ground Truth')
    ax1.plot(x_ekf.cpu().numpy()[:, 0], x_ekf.cpu().numpy()[:, 1], 'r--', lw=1.5, label='EKF')
    ax1.plot(bkn_np[:, 0], bkn_np[:, 1], 'b-.', lw=1.5, label='BKN')
    ax1.set_title(f'Traj {i+1}: 2D Position')
    ax1.set_xlabel('East [m]'); ax1.set_ylabel('North [m]')
    ax1.legend(); ax1.grid(True); ax1.axis('equal')

    # Graf 2: Time Series X s Confidence Tube
    ax2.plot(t_axis, gt_np[:, 0], 'k-', lw=1, label='GT X')
    ax2.plot(t_axis, bkn_np[:, 0], 'b-', lw=1, label='BKN X')
    ax2.fill_between(t_axis, 
                     bkn_np[:, 0] - 3*std_x_bkn, 
                     bkn_np[:, 0] + 3*std_x_bkn, 
                     color='blue', alpha=0.2, label='3$\sigma$ Uncertainty')
    ax2.set_title(f'X-Coord Uncertainty (ANEES: {anees_bkn:.2f})')
    ax2.set_xlabel('Time Step'); ax2.set_ylabel('X Position [m]')
    ax2.legend(); ax2.grid(True)
    
    plt.tight_layout()
    plt.show()

# ==============================================================================
# 2. FINÁLNÍ SOUHRN
# ==============================================================================
print("\n" + "="*80)
print(f"PRŮMĚRNÉ VÝSLEDKY ({len(test_data_raw)} trajektorií)")
print("="*80)
print(f"{'Metoda':<10} | {'MSE':<12} | {'RMSE':<12} | {'ANEES':<12}")
print("-" * 80)
print(f"{'BKN':<10} | {np.nanmean(results['BKN_MSE']):<12.2f} | {np.sqrt(np.nanmean(results['BKN_MSE'])):<12.2f} | {np.nanmean(results['BKN_ANEES']):<12.2f}")
print(f"{'EKF':<10} | {np.nanmean(results['EKF_MSE']):<12.2f} | {np.sqrt(np.nanmean(results['EKF_MSE'])):<12.2f} | {np.nanmean(results['EKF_ANEES']):<12.2f}")
print("="*80)
# Out:
# INFO: Nastaveno sys_model.dt = 1.0 s
# INFO: Používám Bayesian KalmanNet s J=50 vzorky.
#
# Spouštím detailní evaluaci na 3 trajektoriích...
#
# -----------------------------------------------------------------------------------------------
# TRAJEKTORIE  | BKN MSE    | BKN ANEES  | EKF MSE    | EKF ANEES  | GPS MSE
# -----------------------------------------------------------------------------------------------
# 1            | 223.97     | 35.78      | 443.11     | 1027.02    | 164.46
# 2            | 48.66      | 44.27      | 221.68     | 445.10     | 51.13
# 3            | 52.77      | 109.65     | 128.44     | 311.25     | 39.94
# ================================================================================
# PRŮMĚRNÉ VÝSLEDKY (3 trajektorií)
# ================================================================================
# Metoda     | MSE          | RMSE         | ANEES
# --------------------------------------------------------------------------------
# BKN        | 108.47       | 10.41        | 63.23
# EKF        | 264.41       | 16.26        | 594.46
# ================================================================================
